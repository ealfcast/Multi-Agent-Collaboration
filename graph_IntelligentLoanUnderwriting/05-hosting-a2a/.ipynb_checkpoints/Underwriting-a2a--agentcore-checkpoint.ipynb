# %% [markdown]
# ## Getting Started with AgentCore, Strands Agents and A2A
#
# [A2A protocol](https://a2a-protocol.org/dev/specification/) is an open standard designed to facilitate communication and interoperability between independent, potentially opaque AI agent systems. In an ecosystem where agents might be built using different frameworks, languages, or by different vendors, A2A provides a common language and interaction model.
#
# [Amazon AgentCore Runtime](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/agents-tools-runtime.html) provides a secure, serverless and purpose-built hosting environment for deploying and running AI agents or tools.
#
# Recently, AWS announced [A2A support](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/runtime-a2a.html) for AgentCore Runtime.
#
# In this workshop, you are going to build following architecture, using AgentCore Runtime:
#
# <img src="images/architecture-getting-started.png" style="width: 80%;">
#
# In this getting started notebook, we are going to build two agents. First agent is an AWS Docs expert. It will query AWS Docs MCP to read and search AWS Documentation and also generate recommendations. Second agent is an AWS Blog expert. It will use websearch to look into AWS latest blogs and news.
#
# So let's get started!

# %% [markdown]
# ### Setup
#
# Install dependencies

# %%
# %pip install -q -r requirements.txt --no-cache-dir --force-reinstall
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.2 requires nvidia-ml-py3==7.352.0, which is not installed.
# dash 2.18.1 requires dash-core-components==2.0.0, which is not installed.
# dash 2.18.1 requires dash-html-components==2.0.0, which is not installed.
# dash 2.18.1 requires dash-table==5.0.0, which is not installed.
# jupyter-ai 2.30.0 requires faiss-cpu!=1.8.0.post0,<2.0.0,>=1.8.0, which is not installed.
# aiobotocore 2.21.1 requires botocore<1.37.2,>=1.37.0, but you have botocore 1.40.76 which is incompatible.
# autogluon-multimodal 1.2 requires jsonschema<4.22,>=4.18, but you have jsonschema 4.25.1 which is incompatible.
# autogluon-multimodal 1.2 requires nltk<3.9,>=3.4.5, but you have nltk 3.9.1 which is incompatible.
# autogluon-multimodal 1.2 requires omegaconf<2.3.0,>=2.1.1, but you have omegaconf 2.3.0 which is incompatible.
# autogluon-multimodal 1.2 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.52.1 which is incompatible.
# autogluon-timeseries 1.2 requires coreforecast==0.0.12, but you have coreforecast 0.0.16 which is incompatible.
# autogluon-timeseries 1.2 requires mlforecast==0.13.4, but you have mlforecast 0.13.6 which is incompatible.
# autogluon-timeseries 1.2 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.52.1 which is incompatible.
# dash 2.18.1 requires Flask<3.1,>=1.0.4, but you have flask 3.1.1 which is incompatible.
# dash 2.18.1 requires Werkzeug<3.1, but you have werkzeug 3.1.3 which is incompatible.
# flake8 7.1.2 requires pycodestyle<2.13.0,>=2.12.0, but you have pycodestyle 2.14.0 which is incompatible.
# langchain-core 0.3.60 requires packaging<25,>=23.2, but you have packaging 25.0 which is incompatible.
# lightning 2.5.1.post0 requires packaging<25.0,>=20.0, but you have packaging 25.0 which is incompatible.
# mdit-py-plugins 0.4.2 requires markdown-it-py<4.0.0,>=1.0.0, but you have markdown-it-py 4.0.0 which is incompatible.
# mlflow 2.21.3 requires cachetools<6,>=5.0.0, but you have cachetools 6.2.2 which is incompatible.
# mlflow 2.21.3 requires packaging<25, but you have packaging 25.0 which is incompatible.
# mlflow 2.21.3 requires protobuf<6,>=3.12.0, but you have protobuf 6.33.1 which is incompatible.
# mlflow-skinny 2.21.3 requires cachetools<6,>=5.0.0, but you have cachetools 6.2.2 which is incompatible.
# mlflow-skinny 2.21.3 requires packaging<25, but you have packaging 25.0 which is incompatible.
# mlflow-skinny 2.21.3 requires protobuf<6,>=3.12.0, but you have protobuf 6.33.1 which is incompatible.
# pyopenssl 25.1.0 requires cryptography<46,>=41.0.5, but you have cryptography 46.0.3 which is incompatible.
# sagemaker 2.242.0 requires attrs<24,>=23.1.0, but you have attrs 25.4.0 which is incompatible.
# sagemaker 2.242.0 requires importlib-metadata<7.0,>=1.4.0, but you have importlib-metadata 8.7.0 which is incompatible.
# sagemaker 2.242.0 requires protobuf<6.0,>=3.12, but you have protobuf 6.33.1 which is incompatible.
# sagemaker-core 1.0.34 requires importlib-metadata<7.0,>=1.4.0, but you have importlib-metadata 8.7.0 which is incompatible.
# sagemaker-studio-analytics-extension 0.1.7 requires sparkmagic==0.22.0, but you have sparkmagic 0.21.0 which is incompatible.
# snowflake-connector-python 3.15.0 requires cffi<2.0.0,>=1.9, but you have cffi 2.0.0 which is incompatible.
# spacy 3.8.6 requires thinc<8.4.0,>=8.3.4, but you have thinc 8.3.2 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.3 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.1 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Please restart your environment, so it can reflect new versions!**

# %%
import IPython

IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %% [markdown]
# Checking if `bedrock-agentcore-starter-toolkit` version is 0.1.21

# %%
# !pip freeze | grep boto
# !pip freeze | grep agentcore
# Out:
# aioboto3 @ file:///home/conda/feedstock_root/build_artifacts/aioboto3_1742196379442/work
# aiobotocore @ file:///home/conda/feedstock_root/build_artifacts/aiobotocore_1741606508148/work
# boto3==1.40.50
# botocore==1.40.76
# opentelemetry-instrumentation-boto==0.59b0
# bedrock-agentcore==0.1.7
# bedrock-agentcore-starter-toolkit==0.1.24

# %%
# Import libraries
import os
import json
import requests
import boto3
import time
from boto3.session import Session
from strands.tools import tool

# Get boto session
boto_session = Session()

# %% [markdown]
# ### 1 - Create Code for the two agents

# %% [markdown]
# Create `agents` folder if it's not created.

# %%
![ ! -d "agents" ] && mkdir agents

# %% [markdown]
# #### 1.1 - AWS Docs expert Agent
#
# Firstly let's write our first agent code to a file locally; this agent will later be deployed to AgentCore runtime.

# %%
# %%writefile agents/strands_aws_docs.py
import os
import logging
import asyncio
from mcp import stdio_client, StdioServerParameters
from strands import Agent
from strands.multiagent.a2a import A2AServer
from strands.tools.mcp import MCPClient
from fastapi import FastAPI
import uvicorn

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

app = FastAPI()
runtime_url = os.environ.get('AGENTCORE_RUNTIME_URL', 'http://127.0.0.1:9000/')
host, port = "0.0.0.0", 9000

# Global MCP client with lazy initialization
_mcp_client = None

async def get_mcp_client():
    """Lazy initialization of MCP client with timeout"""
    global _mcp_client
    if _mcp_client is None:
        try:
            _mcp_client = MCPClient(
                lambda: stdio_client(
                    StdioServerParameters(
                        command="uvx", 
                        args=["awslabs.aws-documentation-mcp-server@latest"]
                    )
                )
            )
            # Start with timeout
            await asyncio.wait_for(_mcp_client.start(), timeout=10.0)
            logger.info("MCP client initialized")
        except asyncio.TimeoutError:
            logger.error("MCP client startup timed out")
            _mcp_client = None
        except Exception as e:
            logger.error(f"MCP client failed: {e}")
            _mcp_client = None
    return _mcp_client

system_prompt = """
                You are the Financial Analysis Manager responsible for comprehensive credit evaluation and income verification.
                Your tasks include:

               Step 1: Credit Analysis
                1. Coordinate credit score analysis with Credit Score Agent
                2. Analyze credit history patterns and trends
                3. Evaluate credit utilization and payment history
                4. Assess credit mix and account age
                5. Identify credit red flags or concerns
                6. Provide consolidated credit assessment summary
                
                Focus Areas:
                - FICO/VantageScore analysis
                - Credit report anomalies
                - Recent credit inquiries
                - Derogatory marks evaluation
                - Credit stability assessment
                
                Provide quantitative scores and qualitative insights for decision-making.

                Step 2: Income Verification
                1. Coordinate income verification through multiple sources
                2. Validate employment status and stability
                3. Verify asset declarations and documentation
                4. Cross-reference financial statements
                5. Identify discrepancies or inconsistencies
                6. Provide comprehensive verification summary
                
                Verification Standards:
                - Income source diversity and stability
                - Employment tenure and position
                - Asset liquidity and ownership
                - Documentation authenticity
                - Financial statement consistency

"""

# Initialize agent with minimal tools first
agent = Agent(
    system_prompt=system_prompt, 
    tools=[],  # Start with no tools, add dynamically
    name="Financial Analysis Agent",
    description="An agent to do Financial Analysis.",
)

# Add tools dynamically when MCP is ready
async def setup_agent_tools():
    """Setup agent tools when MCP client is ready"""
    try:
        mcp_client = await get_mcp_client()
        if mcp_client:
            tools = await asyncio.wait_for(
                mcp_client.list_tools_async(), 
                timeout=5.0
            )
            agent.tools = [tools] if tools else []
            logger.info("Agent tools configured")
    except Exception as e:
        logger.warning(f"Could not setup MCP tools: {e}")

a2a_server = A2AServer(
    agent=agent,
    http_url=runtime_url,
    serve_at_root=True
)

@app.get("/ping")
def ping():
    return {"status": "healthy"}

@app.on_event("startup")
async def startup_event():
    """Initialize MCP client on startup"""
    await setup_agent_tools()

app.mount("/", a2a_server.to_fastapi_app())

if __name__ == "__main__":
    uvicorn.run(app, host=host, port=port)
# Out:
# Overwriting agents/strands_aws_docs.py

# %% [markdown]
# #### **Optional** - Local Test
#
# If you want to test this code locally, you can open a bash/terminal window and execute following snippets:
#
# ```bash
# python agents/strands_aws_docs.py
# ```
#
# Server will start locally. Then, run in another terminal/bash following command to test it:
#
# ```bash
# curl -X POST http://0.0.0.0:9000 \-H "Content-Type: application/json" \-d '{  "jsonrpc": "2.0",  "id": "req-001",  "method": "message/send",  "params": {  "message": {  "role": "user",  "parts": [  {  "kind": "text",  "text": "What's AWS Lambda?"  }  ],  "messageId": "d0673ab9-796d-4270-9435-451912020cd1"  }  } }' | jq .
# ```
#
# It will query MCP and then return an answer explaining AWS Lambda.
#
# You can also test agent card information retrieval, using following command:
#
# ```bash
# curl http://localhost:9000/.well-known/agent-card.json | jq .
# ```

# %% [markdown]
# #### 1.2 - Risk Analysis expert Agent
#
# Now, let's write our second agent code to a local file.

# %%
# %%writefile agents/strands_aws_blogs_news.py
import logging
import os
import asyncio
from strands import Agent, tool
from strands.multiagent.a2a import A2AServer
import uvicorn
from fastapi import FastAPI

from ddgs import DDGS
from ddgs.exceptions import RatelimitException, DDGSException

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

runtime_url = os.environ.get('AGENTCORE_RUNTIME_URL', 'http://127.0.0.1:9000/')

@tool
async def fast_internet_search(keywords: str, max_results: int = 3) -> str:
    """Fast web search with timeouts.
    Args:
        keywords (str): Search query keywords
        max_results (int): Max results (default 3 for speed)
    Returns:
        Search results
    """
    try:
        # Add AWS-specific terms for better results
        aws_keywords = f"site:aws.amazon.com {keywords} AWS"
        
        # Use asyncio timeout for the search
        async def search_with_timeout():
            return DDGS().text(
                aws_keywords, 
                region="us-en", 
                max_results=max_results
            )
        
        results = await asyncio.wait_for(search_with_timeout(), timeout=8.0)
        
        if results:
            # Format results concisely
            formatted = []
            for i, result in enumerate(results[:max_results], 1):
                formatted.append(f"{i}. {result.get('title', 'No title')}\n   {result.get('href', '')}")
            
            return "\n".join(formatted)
        else:
            return "No AWS results found."
            
    except asyncio.TimeoutError:
        logger.warning(f"Search timeout for: {keywords}")
        return "Search timed out. Try a more specific query."
    except RatelimitException:
        logger.warning("Rate limit hit")
        return "Rate limit reached. Please try again in a moment."
    except (DDGSException, Exception) as e:
        logger.error(f"Search error: {e}")
        return f"Search unavailable: {str(e)[:50]}"

system_prompt = """
You are the Risk Analysis Manager responsible for evaluating risks and detecting potential fraud. Your duties include:

                Step 1: Risk Calculation Agent specialized in quantitative risk modeling:
                1. Calculate probability of default (PD)
                2. Estimate loss given default (LGD)
                3. Assess exposure at default (EAD)
                4. Compute risk-adjusted pricing
                5. Analyze portfolio concentration risks
                6. Generate risk scores and ratings

                Evaluate borrower risk profile. Risk Categories:
                - Credit risk (default probability)
                - Fraud risk (application authenticity)
                - Market risk (economic factors)
                - Operational risk (process failures)
                - Concentration risk (portfolio impact)
                
                Use statistical models for accurate risk quantification.


                Step 2: Fraud Detection  focused on identifying fraudulent applications:
                1. Analyze application data for inconsistencies
                2. Detect synthetic identity fraud
                3. Identify document manipulation or forgery
                4. Flag suspicious behavioral patterns
                5. Cross-reference against fraud databases
                6. Generate fraud risk scores
                
                Use pattern recognition and anomaly detection techniques.


"""

agent = Agent(
    system_prompt=system_prompt, 
    tools=[],
    name="Risk Analysis Agent",
    description="An agent to do Risk Analysis",
)

host, port = "0.0.0.0", 9000

a2a_server = A2AServer(
    agent=agent,
    http_url=runtime_url,
    serve_at_root=True
)

app = FastAPI()

@app.get("/ping")
def ping():
    return {"status": "healthy"}

app.mount("/", a2a_server.to_fastapi_app())

if __name__ == "__main__":
    uvicorn.run(app, host=host, port=port)
# Out:
# Overwriting agents/strands_aws_blogs_news.py

# %% [markdown]
# Let's write a requirements.txt file with dependencies that are needed for the agent.

# %%
# %%writefile agents/requirements.txt
# boto3==1.40.50
# bedrock-agentcore==0.1.7
# strands-agents[a2a]
# strands-agents-tools
# pyyaml
# ddgs
# Out:
# Overwriting agents/requirements.txt

# %% [markdown]
# ### 2 - Deploy to AgentCore Runtime
#
# Now, let's deploy this solution into AgentCore Runtime.

# %% [markdown]
# #### 2.1 - Setup Cognito User Pool
#
# Before deploy agents, we have to set up a Cognito User Pool, so it can validate users that are accessing our agents, or any other Idenitty provider like Okta, Microsoft Entra ID, etc.
#
# We're going to import a helper class, that has methods to simplify few steps in our workshop. This helper class will import methods responsible to create Cognito User Pool

# %%
from helpers.utils import setup_cognito_user_pool, reauthenticate_user

print("Setting up Amazon Cognito user pool...")
cognito_config = (
    setup_cognito_user_pool()
)  # You'll get your bearer token from this output cell.
print("Cognito setup completed ✓")
# Out:
# Setting up Amazon Cognito user pool...
# Pool id: us-east-1_yeCMhqfh8
# Discovery URL: https://cognito-idp.us-east-1.amazonaws.com/us-east-1_yeCMhqfh8/.well-known/openid-configuration
# Client ID: 7qujfdjt0u15j8qjtldna2sfb3
# Bearer Token: eyJraWQiOiJOYThZWnRaVVdOYVNud3ZPbEtqOUg4SjYrYWhONGNkQm11VXRaRWI2SnQwPSIsImFsZyI6IlJTMjU2In0.....aDyNJZ8J6UBqGo3VuczXmRuB0lomb3QitGP_j3fNKP3cjj-UuMv8XR0hveNO7IzO4XfFlQ7lttKnDY8i9kP60LF8UaTm53LDqydDAzS8smyxQqOeVEm5-vH5VpgyUDl4lcjw0dDoqMTq-SRpq28B43JpUI6_e8rCBe-afaRD37gtTF8ThHq91PFAX-hI1PcYTZfUa1B3VcmtflWq4m2piux9C53pDUcu0yROgbFrrZ8mYc2x-RosEoodOi_mN1H3fmZBx2E0GOQx7OKFVSwbrv65lAQGzVHkofb6KW4u_Qsu4lIa0kG4WzfgGX72nTazfVYEYB0uLvuOVpNiJlOorA
# ✅ Updated existing secret
# Cognito setup completed ✓

# %% [markdown]
# #### 2.2 - Create IAM Role for the Agents

# %% [markdown]
# ##### 2.2.1 AWS Docs Agent Execution Role

# %%
from helpers.utils import create_agentcore_runtime_execution_role, AWS_DOCS_ROLE_NAME

execution_role_arn_mcp = create_agentcore_runtime_execution_role(AWS_DOCS_ROLE_NAME)
# Out:
# ℹ️ Role AWSDocsAssistantBedrockAgentCoreRole-us-east-1 already exists
# Role ARN: arn:aws:iam::161615149547:role/AWSDocsAssistantBedrockAgentCoreRole-us-east-1

# %% [markdown]
# ##### 2.2.2 AWS Blogs Agent Execution Role

# %%
from helpers.utils import create_agentcore_runtime_execution_role, AWS_BLOG_ROLE_NAME

execution_role_arn_blogs = create_agentcore_runtime_execution_role(AWS_BLOG_ROLE_NAME)
# Out:
# ℹ️ Role AWSBlogsAssistantBedrockAgentCoreRole-us-east-1 already exists
# Role ARN: arn:aws:iam::161615149547:role/AWSBlogsAssistantBedrockAgentCoreRole-us-east-1

# %% [markdown]
# ##### Create configurations for deployment on AgentCore Runtime
#
# In following section, we're taking advantage of [starter toolkit](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/getting-started-starter-toolkit.html). The starter toolkit is a Command Line Interface (CLI) toolkit that you can use to deploy AI agents to an AgentCore Runtime.
#
# We will now create an agent with support for A2A protocol inside AgentCore runtime.

# %% [markdown]
# ##### 2.2.3 - Let's configure and deploy our first agent (Financial Analysis Agent):

# %%
from bedrock_agentcore_starter_toolkit import Runtime

agentcore_runtime_mcp_agent = Runtime()
aws_docs_agent_name="financial_analysis_assistant"

region = boto_session.region_name

# Configure the deployment
response_aws_docs_agent = agentcore_runtime_mcp_agent.configure(
    entrypoint="agents/strands_aws_docs.py",
    execution_role=execution_role_arn_mcp,
    auto_create_ecr=True,
    requirements_file="agents/requirements.txt",
    region=region,
    agent_name=aws_docs_agent_name,
    authorizer_configuration={
        "customJWTAuthorizer": {
            "allowedClients": [cognito_config.get("client_id")],
            "discoveryUrl": cognito_config.get("discovery_url"),
        }
    },
    protocol="A2A",
)

print("Configuration completed:", response_aws_docs_agent)
# Out:
# Entrypoint parsed: file=/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/agents/strands_aws_docs.py, bedrock_agentcore_name=strands_aws_docs
# INFO:bedrock_agentcore_starter_toolkit.utils.runtime.entrypoint:Entrypoint parsed: file=/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/agents/strands_aws_docs.py, bedrock_agentcore_name=strands_aws_docs
# Memory configured with STM only
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:Memory configured with STM only
# Configuring BedrockAgentCore agent: financial_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Configuring BedrockAgentCore agent: financial_analysis_assistant
# 💡 No container engine found (Docker/Finch/Podman not installed)
# ✓ Default deployment uses CodeBuild (no container engine needed), For local builds, install Docker, Finch, or
# Podman
# Will create new memory with mode: STM_ONLY
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Will create new memory with mode: STM_ONLY
# Memory configuration: Short-term memory only
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Memory configuration: Short-term memory only
# Found existing memory ID from previous launch: financial_analysis_assistant_mem-9Dw3xVEUYh
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Found existing memory ID from previous launch: financial_analysis_assistant_mem-9Dw3xVEUYh
# ⚠️ Platform mismatch: Current system is 'linux/amd64' but Bedrock AgentCore requires 'linux/arm64', so local builds
# won't work.
# Please use default launch command which will do a remote cross-platform build using code build.For deployment other
# options and workarounds, see:
# https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/getting-started-custom.html
# Generated Dockerfile: Dockerfile
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Generated Dockerfile: Dockerfile
# Generated .dockerignore: /home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.dockerignore
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Generated .dockerignore: /home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.dockerignore
# Changing default agent from 'risk_analysis_assistant' to 'financial_analysis_assistant'
# INFO:bedrock_agentcore_starter_toolkit.utils.runtime.config:Changing default agent from 'risk_analysis_assistant' to 'financial_analysis_assistant'
# Bedrock AgentCore configured: /home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.bedrock_agentcore.yaml
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:Bedrock AgentCore configured: /home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.bedrock_agentcore.yaml
# Configuration completed: config_path=PosixPath('/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.bedrock_agentcore.yaml') dockerfile_path=PosixPath('/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/Dockerfile') dockerignore_path=PosixPath('/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.dockerignore') runtime='None' region='us-east-1' account_id='161615149547' execution_role='arn:aws:iam::161615149547:role/AWSDocsAssistantBedrockAgentCoreRole-us-east-1' ecr_repository=None auto_create_ecr=True memory_id=None

# %% [markdown]
# Launch the first agent on AgentCore Runtime

# %%
launch_result_mcp = agentcore_runtime_mcp_agent.launch()
print("Launch completed:", launch_result_mcp.agent_arn)

financial_analysis_agent_arn = launch_result_mcp.agent_arn
# Out:
# 🚀 CodeBuild mode: building in cloud (RECOMMENDED - DEFAULT)
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:🚀 CodeBuild mode: building in cloud (RECOMMENDED - DEFAULT)
#    • Build ARM64 containers in the cloud with CodeBuild
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   • Build ARM64 containers in the cloud with CodeBuild
#    • No local Docker required
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   • No local Docker required
# 💡 Available deployment modes:
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:💡 Available deployment modes:
#    • runtime.launch()                           → CodeBuild (current)
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   • runtime.launch()                           → CodeBuild (current)
#    • runtime.launch(local=True)                 → Local development
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   • runtime.launch(local=True)                 → Local development
#    • runtime.launch(local_build=True)           → Local build + cloud deploy (NEW)
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   • runtime.launch(local_build=True)           → Local build + cloud deploy (NEW)
# Creating memory resource for agent: financial_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Creating memory resource for agent: financial_analysis_assistant
# ✅ MemoryManager initialized for region: us-east-1
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:✅ MemoryManager initialized for region: us-east-1
# 🔎 Retrieving memory resource with ID: financial_analysis_assistant_mem-9Dw3xVEUYh...
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:🔎 Retrieving memory resource with ID: financial_analysis_assistant_mem-9Dw3xVEUYh...
#   Found memory: financial_analysis_assistant_mem-9Dw3xVEUYh
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:  Found memory: financial_analysis_assistant_mem-9Dw3xVEUYh
# Found existing memory in cloud: financial_analysis_assistant_mem-9Dw3xVEUYh
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Found existing memory in cloud: financial_analysis_assistant_mem-9Dw3xVEUYh
# Existing memory has 0 strategies
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Existing memory has 0 strategies
# ✅ Using existing STM-only memory
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:✅ Using existing STM-only memory
# Starting CodeBuild ARM64 deployment for agent 'financial_analysis_assistant' to account 161615149547 (us-east-1)
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Starting CodeBuild ARM64 deployment for agent 'financial_analysis_assistant' to account 161615149547 (us-east-1)
# Setting up AWS resources (ECR repository, execution roles)...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: financial_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Getting or creating ECR repository for agent: financial_analysis_assistant
# ✅ ECR repository available: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-financial_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:✅ ECR repository available: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-financial_analysis_assistant
# Using execution role from config: arn:aws:iam::161615149547:role/AWSDocsAssistantBedrockAgentCoreRole-us-east-1
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Using execution role from config: arn:aws:iam::161615149547:role/AWSDocsAssistantBedrockAgentCoreRole-us-east-1
# Preparing CodeBuild project and uploading source...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Preparing CodeBuild project and uploading source...
# Getting or creating CodeBuild execution role for agent: financial_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Getting or creating CodeBuild execution role for agent: financial_analysis_assistant
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-e6d4c4c8ab
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-e6d4c4c8ab
# ✅ Reusing existing ECR repository: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-financial_analysis_assistant
# Reusing existing CodeBuild execution role: arn:aws:iam::161615149547:role/AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-e6d4c4c8ab
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Reusing existing CodeBuild execution role: arn:aws:iam::161615149547:role/AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-e6d4c4c8ab
# Using dockerignore.template with 45 patterns for zip filtering
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Using dockerignore.template with 45 patterns for zip filtering
# Uploaded source to S3: financial_analysis_assistant/source.zip
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Uploaded source to S3: financial_analysis_assistant/source.zip
# Updated CodeBuild project: bedrock-agentcore-financial_analysis_assistant-builder
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Updated CodeBuild project: bedrock-agentcore-financial_analysis_assistant-builder
# Starting CodeBuild build (this may take several minutes)...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.0s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ QUEUED completed in 1.0s
# 🔄 PROVISIONING started (total: 1s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 9.3s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ PROVISIONING completed in 9.3s
# 🔄 DOWNLOAD_SOURCE started (total: 10s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 DOWNLOAD_SOURCE started (total: 10s)
# ✅ DOWNLOAD_SOURCE completed in 2.1s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ DOWNLOAD_SOURCE completed in 2.1s
# 🔄 BUILD started (total: 12s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 BUILD started (total: 12s)
# ✅ BUILD completed in 16.6s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ BUILD completed in 16.6s
# 🔄 POST_BUILD started (total: 29s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 POST_BUILD started (total: 29s)
# ✅ POST_BUILD completed in 12.4s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ POST_BUILD completed in 12.4s
# 🔄 FINALIZING started (total: 41s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 FINALIZING started (total: 41s)
# ✅ FINALIZING completed in 1.0s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ FINALIZING completed in 1.0s
# 🔄 COMPLETED started (total: 42s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 COMPLETED started (total: 42s)
# ✅ COMPLETED completed in 1.0s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ COMPLETED completed in 1.0s
# 🎉 CodeBuild completed successfully in 0m 43s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🎉 CodeBuild completed successfully in 0m 43s
# CodeBuild completed successfully
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:CodeBuild completed successfully
# ✅ CodeBuild project configuration saved
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:✅ CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Deploying to Bedrock AgentCore...
# Passing memory configuration to agent: financial_analysis_assistant_mem-9Dw3xVEUYh
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Passing memory configuration to agent: financial_analysis_assistant_mem-9Dw3xVEUYh
# ✅ Agent created/updated: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/financial_analysis_assistant-mqZxfd4lJ4
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:✅ Agent created/updated: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/financial_analysis_assistant-mqZxfd4lJ4
# Observability is enabled, configuring Transaction Search...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Observability is enabled, configuring Transaction Search...
# CloudWatch Logs resource policy already configured
# INFO:bedrock_agentcore_starter_toolkit.services.xray:CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# INFO:bedrock_agentcore_starter_toolkit.services.xray:X-Ray trace destination already configured
# X-Ray indexing rule already configured
# INFO:bedrock_agentcore_starter_toolkit.services.xray:X-Ray indexing rule already configured
# ✅ Transaction Search already fully configured
# INFO:bedrock_agentcore_starter_toolkit.services.xray:✅ Transaction Search already fully configured
# 🔍 GenAI Observability Dashboard:
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-east-1#gen-ai-observability/agent-core
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:   https://console.aws.amazon.com/cloudwatch/home?region=us-east-1#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/financial_analysis_assistant-mqZxfd4lJ4/runtime-endpoint/DEFAULT
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Agent endpoint: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/financial_analysis_assistant-mqZxfd4lJ4/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/financial_analysis_assistant-mqZxfd4lJ4
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/financial_analysis_assistant-mqZxfd4lJ4
# Built with CodeBuild: bedrock-agentcore-financial_analysis_assistant-builder:6941f55b-a844-4f25-9cf2-b3c5e0515645
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:Built with CodeBuild: bedrock-agentcore-financial_analysis_assistant-builder:6941f55b-a844-4f25-9cf2-b3c5e0515645
# Deployed to cloud: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/financial_analysis_assistant-mqZxfd4lJ4
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:Deployed to cloud: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/financial_analysis_assistant-mqZxfd4lJ4
# ECR image: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-financial_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:ECR image: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-financial_analysis_assistant
# 🔍 Agent logs available at:
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/financial_analysis_assistant-mqZxfd4lJ4-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]"
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   /aws/bedrock-agentcore/runtimes/financial_analysis_assistant-mqZxfd4lJ4-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/financial_analysis_assistant-mqZxfd4lJ4-DEFAULT --log-stream-names "otel-rt-logs"
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   /aws/bedrock-agentcore/runtimes/financial_analysis_assistant-mqZxfd4lJ4-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/financial_analysis_assistant-mqZxfd4lJ4-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]" --follow
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/financial_analysis_assistant-mqZxfd4lJ4-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/financial_analysis_assistant-mqZxfd4lJ4-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]" --since 1h
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/financial_analysis_assistant-mqZxfd4lJ4-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]" --since 1h
# Launch completed: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/financial_analysis_assistant-mqZxfd4lJ4

# %% [markdown]
# **Check Deployment Status**
#
# Let's check if deployment is completed:

# %%
status_response = agentcore_runtime_mcp_agent.status()
status = status_response.endpoint["status"]

print(f"Final status: {status}")
# Out:
# ✅ MemoryManager initialized for region: us-east-1
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:✅ MemoryManager initialized for region: us-east-1
# 🔎 Retrieving memory resource with ID: financial_analysis_assistant_mem-9Dw3xVEUYh...
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:🔎 Retrieving memory resource with ID: financial_analysis_assistant_mem-9Dw3xVEUYh...
#   Found memory: financial_analysis_assistant_mem-9Dw3xVEUYh
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:  Found memory: financial_analysis_assistant_mem-9Dw3xVEUYh
# Retrieved Bedrock AgentCore status for: financial_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:Retrieved Bedrock AgentCore status for: financial_analysis_assistant
# Final status: READY

# %% [markdown]
# ##### 2.2.4 - Let's configure and deploy our second agent (AWS Blogs and News Agent):

# %%
from bedrock_agentcore_starter_toolkit import Runtime

agentcore_runtime_blogs = Runtime()
aws_blogs_agent_name="risk_analysis_assistant"

# Configure the deployment
response_aws_blogs_agent = agentcore_runtime_blogs.configure(
    entrypoint="agents/strands_aws_blogs_news.py",
    execution_role=execution_role_arn_blogs,
    auto_create_ecr=True,
    requirements_file="agents/requirements.txt",
    region=region,
    agent_name=aws_blogs_agent_name,
    authorizer_configuration={
        "customJWTAuthorizer": {
            "allowedClients": [cognito_config.get("client_id")],
            "discoveryUrl": cognito_config.get("discovery_url"),
        }
    },
    protocol="A2A"
)

print("Configuration completed:", response_aws_blogs_agent)
# Out:
# Entrypoint parsed: file=/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/agents/strands_aws_blogs_news.py, bedrock_agentcore_name=strands_aws_blogs_news
# INFO:bedrock_agentcore_starter_toolkit.utils.runtime.entrypoint:Entrypoint parsed: file=/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/agents/strands_aws_blogs_news.py, bedrock_agentcore_name=strands_aws_blogs_news
# Memory configured with STM only
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:Memory configured with STM only
# Configuring BedrockAgentCore agent: risk_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Configuring BedrockAgentCore agent: risk_analysis_assistant
# 💡 No container engine found (Docker/Finch/Podman not installed)
# ✓ Default deployment uses CodeBuild (no container engine needed), For local builds, install Docker, Finch, or
# Podman
# Will create new memory with mode: STM_ONLY
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Will create new memory with mode: STM_ONLY
# Memory configuration: Short-term memory only
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Memory configuration: Short-term memory only
# Found existing memory ID from previous launch: risk_analysis_assistant_mem-9Nsgez6ReJ
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Found existing memory ID from previous launch: risk_analysis_assistant_mem-9Nsgez6ReJ
# ⚠️ Platform mismatch: Current system is 'linux/amd64' but Bedrock AgentCore requires 'linux/arm64', so local builds
# won't work.
# Please use default launch command which will do a remote cross-platform build using code build.For deployment other
# options and workarounds, see:
# https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/getting-started-custom.html
# Generated Dockerfile: Dockerfile
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Generated Dockerfile: Dockerfile
# Generated .dockerignore: /home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.dockerignore
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.configure:Generated .dockerignore: /home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.dockerignore
# Changing default agent from 'financial_analysis_assistant' to 'risk_analysis_assistant'
# INFO:bedrock_agentcore_starter_toolkit.utils.runtime.config:Changing default agent from 'financial_analysis_assistant' to 'risk_analysis_assistant'
# Bedrock AgentCore configured: /home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.bedrock_agentcore.yaml
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:Bedrock AgentCore configured: /home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.bedrock_agentcore.yaml
# Configuration completed: config_path=PosixPath('/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.bedrock_agentcore.yaml') dockerfile_path=PosixPath('/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/Dockerfile') dockerignore_path=PosixPath('/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.dockerignore') runtime='None' region='us-east-1' account_id='161615149547' execution_role='arn:aws:iam::161615149547:role/AWSBlogsAssistantBedrockAgentCoreRole-us-east-1' ecr_repository=None auto_create_ecr=True memory_id=None

# %% [markdown]
# Launch the second agent on AgentCore Runtime

# %%
launch_result_blog = agentcore_runtime_blogs.launch()
print("Launch completed:", launch_result_blog.agent_arn)

blog_agent_arn = launch_result_blog.agent_arn
# Out:
# 🚀 CodeBuild mode: building in cloud (RECOMMENDED - DEFAULT)
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:🚀 CodeBuild mode: building in cloud (RECOMMENDED - DEFAULT)
#    • Build ARM64 containers in the cloud with CodeBuild
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   • Build ARM64 containers in the cloud with CodeBuild
#    • No local Docker required
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   • No local Docker required
# 💡 Available deployment modes:
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:💡 Available deployment modes:
#    • runtime.launch()                           → CodeBuild (current)
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   • runtime.launch()                           → CodeBuild (current)
#    • runtime.launch(local=True)                 → Local development
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   • runtime.launch(local=True)                 → Local development
#    • runtime.launch(local_build=True)           → Local build + cloud deploy (NEW)
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   • runtime.launch(local_build=True)           → Local build + cloud deploy (NEW)
# Creating memory resource for agent: risk_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Creating memory resource for agent: risk_analysis_assistant
# ✅ MemoryManager initialized for region: us-east-1
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:✅ MemoryManager initialized for region: us-east-1
# 🔎 Retrieving memory resource with ID: risk_analysis_assistant_mem-9Nsgez6ReJ...
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:🔎 Retrieving memory resource with ID: risk_analysis_assistant_mem-9Nsgez6ReJ...
#   Found memory: risk_analysis_assistant_mem-9Nsgez6ReJ
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:  Found memory: risk_analysis_assistant_mem-9Nsgez6ReJ
# Found existing memory in cloud: risk_analysis_assistant_mem-9Nsgez6ReJ
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Found existing memory in cloud: risk_analysis_assistant_mem-9Nsgez6ReJ
# Existing memory has 0 strategies
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Existing memory has 0 strategies
# ✅ Using existing STM-only memory
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:✅ Using existing STM-only memory
# Starting CodeBuild ARM64 deployment for agent 'risk_analysis_assistant' to account 161615149547 (us-east-1)
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Starting CodeBuild ARM64 deployment for agent 'risk_analysis_assistant' to account 161615149547 (us-east-1)
# Setting up AWS resources (ECR repository, execution roles)...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: risk_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Getting or creating ECR repository for agent: risk_analysis_assistant
# ✅ ECR repository available: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-risk_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:✅ ECR repository available: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-risk_analysis_assistant
# Using execution role from config: arn:aws:iam::161615149547:role/AWSBlogsAssistantBedrockAgentCoreRole-us-east-1
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Using execution role from config: arn:aws:iam::161615149547:role/AWSBlogsAssistantBedrockAgentCoreRole-us-east-1
# Preparing CodeBuild project and uploading source...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Preparing CodeBuild project and uploading source...
# Getting or creating CodeBuild execution role for agent: risk_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Getting or creating CodeBuild execution role for agent: risk_analysis_assistant
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-828433ada5
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-828433ada5
# ✅ Reusing existing ECR repository: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-risk_analysis_assistant
# Reusing existing CodeBuild execution role: arn:aws:iam::161615149547:role/AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-828433ada5
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Reusing existing CodeBuild execution role: arn:aws:iam::161615149547:role/AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-828433ada5
# Using dockerignore.template with 45 patterns for zip filtering
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Using dockerignore.template with 45 patterns for zip filtering
# Uploaded source to S3: risk_analysis_assistant/source.zip
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Uploaded source to S3: risk_analysis_assistant/source.zip
# Updated CodeBuild project: bedrock-agentcore-risk_analysis_assistant-builder
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Updated CodeBuild project: bedrock-agentcore-risk_analysis_assistant-builder
# Starting CodeBuild build (this may take several minutes)...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.0s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ QUEUED completed in 1.0s
# 🔄 PROVISIONING started (total: 1s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 7.2s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ PROVISIONING completed in 7.2s
# 🔄 DOWNLOAD_SOURCE started (total: 8s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 DOWNLOAD_SOURCE started (total: 8s)
# ✅ DOWNLOAD_SOURCE completed in 2.1s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ DOWNLOAD_SOURCE completed in 2.1s
# 🔄 BUILD started (total: 10s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 BUILD started (total: 10s)
# ✅ BUILD completed in 16.5s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ BUILD completed in 16.5s
# 🔄 POST_BUILD started (total: 27s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 POST_BUILD started (total: 27s)
# ✅ POST_BUILD completed in 12.4s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ POST_BUILD completed in 12.4s
# 🔄 FINALIZING started (total: 39s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 FINALIZING started (total: 39s)
# ✅ FINALIZING completed in 1.0s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ FINALIZING completed in 1.0s
# 🔄 COMPLETED started (total: 40s)
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🔄 COMPLETED started (total: 40s)
# ✅ COMPLETED completed in 1.0s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:✅ COMPLETED completed in 1.0s
# 🎉 CodeBuild completed successfully in 0m 41s
# INFO:bedrock_agentcore_starter_toolkit.services.codebuild:🎉 CodeBuild completed successfully in 0m 41s
# CodeBuild completed successfully
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:CodeBuild completed successfully
# ✅ CodeBuild project configuration saved
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:✅ CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Deploying to Bedrock AgentCore...
# Passing memory configuration to agent: risk_analysis_assistant_mem-9Nsgez6ReJ
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Passing memory configuration to agent: risk_analysis_assistant_mem-9Nsgez6ReJ
# ✅ Agent created/updated: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/risk_analysis_assistant-9QOgL4F5WE
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:✅ Agent created/updated: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/risk_analysis_assistant-9QOgL4F5WE
# Observability is enabled, configuring Transaction Search...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Observability is enabled, configuring Transaction Search...
# CloudWatch Logs resource policy already configured
# INFO:bedrock_agentcore_starter_toolkit.services.xray:CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# INFO:bedrock_agentcore_starter_toolkit.services.xray:X-Ray trace destination already configured
# X-Ray indexing rule already configured
# INFO:bedrock_agentcore_starter_toolkit.services.xray:X-Ray indexing rule already configured
# ✅ Transaction Search already fully configured
# INFO:bedrock_agentcore_starter_toolkit.services.xray:✅ Transaction Search already fully configured
# 🔍 GenAI Observability Dashboard:
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-east-1#gen-ai-observability/agent-core
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:   https://console.aws.amazon.com/cloudwatch/home?region=us-east-1#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/risk_analysis_assistant-9QOgL4F5WE/runtime-endpoint/DEFAULT
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Agent endpoint: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/risk_analysis_assistant-9QOgL4F5WE/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/risk_analysis_assistant-9QOgL4F5WE
# INFO:bedrock_agentcore_starter_toolkit.operations.runtime.launch:Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/risk_analysis_assistant-9QOgL4F5WE
# Built with CodeBuild: bedrock-agentcore-risk_analysis_assistant-builder:ca92ba43-ef97-4740-9f4c-a9099fb353fc
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:Built with CodeBuild: bedrock-agentcore-risk_analysis_assistant-builder:ca92ba43-ef97-4740-9f4c-a9099fb353fc
# Deployed to cloud: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/risk_analysis_assistant-9QOgL4F5WE
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:Deployed to cloud: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/risk_analysis_assistant-9QOgL4F5WE
# ECR image: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-risk_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:ECR image: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-risk_analysis_assistant
# 🔍 Agent logs available at:
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/risk_analysis_assistant-9QOgL4F5WE-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]"
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   /aws/bedrock-agentcore/runtimes/risk_analysis_assistant-9QOgL4F5WE-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/risk_analysis_assistant-9QOgL4F5WE-DEFAULT --log-stream-names "otel-rt-logs"
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:   /aws/bedrock-agentcore/runtimes/risk_analysis_assistant-9QOgL4F5WE-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/risk_analysis_assistant-9QOgL4F5WE-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]" --follow
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/risk_analysis_assistant-9QOgL4F5WE-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/risk_analysis_assistant-9QOgL4F5WE-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]" --since 1h
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/risk_analysis_assistant-9QOgL4F5WE-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]" --since 1h
# Launch completed: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/risk_analysis_assistant-9QOgL4F5WE

# %% [markdown]
# **Check Deployment Status**
#
# Let's check if deployment of second agent is completed:

# %%
status_response = agentcore_runtime_blogs.status()
status = status_response.endpoint["status"]

print(f"Final status: {status}")
# Out:
# ✅ MemoryManager initialized for region: us-east-1
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:✅ MemoryManager initialized for region: us-east-1
# 🔎 Retrieving memory resource with ID: risk_analysis_assistant_mem-9Nsgez6ReJ...
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:🔎 Retrieving memory resource with ID: risk_analysis_assistant_mem-9Nsgez6ReJ...
#   Found memory: risk_analysis_assistant_mem-9Nsgez6ReJ
# INFO:bedrock_agentcore_starter_toolkit.operations.memory.manager:  Found memory: risk_analysis_assistant_mem-9Nsgez6ReJ
# Retrieved Bedrock AgentCore status for: risk_analysis_assistant
# INFO:bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore:Retrieved Bedrock AgentCore status for: risk_analysis_assistant
# Final status: READY

# %% [markdown]
# ##### 2.2.5 - Export and save outputs
#
# Export variables to be used in next notebooks:

# %%
MCP_AGENT_ID = launch_result_mcp.agent_id
MCP_AGENT_ARN = launch_result_mcp.agent_arn
MCP_AGENT_NAME = aws_docs_agent_name

BLOG_AGENT_ID = launch_result_blog.agent_id
BLOG_AGENT_ARN = launch_result_blog.agent_arn
BLOG_AGENT_NAME = aws_blogs_agent_name

COGNITO_CLIENT_ID = cognito_config.get("client_id")
COGNITO_SECRET = cognito_config.get("client_secret")
DISCOVERY_URL = cognito_config.get("discovery_url")

# %store MCP_AGENT_ID
# %store MCP_AGENT_ARN
# %store MCP_AGENT_NAME
# %store BLOG_AGENT_ID
# %store BLOG_AGENT_ARN
# %store BLOG_AGENT_NAME
# %store COGNITO_CLIENT_ID
# %store COGNITO_SECRET
# %store DISCOVERY_URL
# Out:
# Stored 'MCP_AGENT_ID' (str)
# Stored 'MCP_AGENT_ARN' (str)
# Stored 'MCP_AGENT_NAME' (str)
# Stored 'BLOG_AGENT_ID' (str)
# Stored 'BLOG_AGENT_ARN' (str)
# Stored 'BLOG_AGENT_NAME' (str)
# Stored 'COGNITO_CLIENT_ID' (str)
# Stored 'COGNITO_SECRET' (str)
# Stored 'DISCOVERY_URL' (str)

# %% [markdown]
# Store ARN of the agents in SSM, so it can be used by orchestrator:

# %%
from helpers.utils import put_ssm_parameter, SSM_DOCS_AGENT_ARN, SSM_BLOGS_AGENT_ARN

put_ssm_parameter(SSM_DOCS_AGENT_ARN, MCP_AGENT_ARN)

put_ssm_parameter(SSM_BLOGS_AGENT_ARN, BLOG_AGENT_ARN)

# %% [markdown]
# ### 3 - Invoking A2A agents
#
# Firstly, let's refresh the auth token:

# %%
bearer_token = reauthenticate_user(
    cognito_config.get("client_id"), 
    cognito_config.get("client_secret")
)

# %% [markdown]
# #### 3.1 Getting Agent Cards
#
# Now let's get started by getting the Agent Card information from our orchestrator agent:

# %%
import logging
from uuid import uuid4
from urllib.parse import quote

logging.basicConfig(level=logging.ERROR)
logger = logging.getLogger(__name__)

def fetch_agent_card(agent_arn):
    # URL encode the agent ARN
    escaped_agent_arn = quote(agent_arn, safe='')

    # Construct the URL
    url = f"https://bedrock-agentcore.{region}.amazonaws.com/runtimes/{escaped_agent_arn}/invocations/.well-known/agent-card.json"
    logger.info(url)
    # Generate a unique session ID
    session_id = str(uuid4())
    logger.info(f"Generated session ID: {session_id}")

    # Set headers
    headers = {
        'Accept': '*/*',
        'Authorization': f'Bearer {bearer_token}',
        'X-Amzn-Bedrock-AgentCore-Runtime-Session-Id': session_id,
        'X-Amzn-Trace-Id': f'aws_docs_assistant_{session_id}'
    }

    try:
        # Make the request
        response = requests.get(url, headers=headers)
        response.raise_for_status()

        # Parse and pretty print JSON
        agent_card = response.json()
        logger.info(json.dumps(agent_card, indent=2))

        return agent_card

    except requests.exceptions.RequestException as e:
        logger.error(f"Error fetching agent card: {e}")
        return None

# %%
fetch_agent_card(financial_analysis_agent_arn)
# Out:
# {'capabilities': {'streaming': True},
#  'defaultInputModes': ['text'],
#  'defaultOutputModes': ['text'],
#  'description': 'An agent to do Financial Analysis.',
#  'name': 'Financial Analysis Agent',
#  'preferredTransport': 'JSONRPC',
#  'protocolVersion': '0.3.0',
#  'skills': [],
#  'url': 'https://bedrock-agentcore.us-east-1.amazonaws.com/runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A161615149547%3Aruntime%2Ffinancial_analysis_assistant-mqZxfd4lJ4/invocations/',
#  'version': '0.0.1'}

# %% [markdown]
# Not let's check the agent card for the second agent (Risk Analysis expert):

# %%
fetch_agent_card(blog_agent_arn)
# Out:
# {'capabilities': {'streaming': True},
#  'defaultInputModes': ['text'],
#  'defaultOutputModes': ['text'],
#  'description': 'An agent to do Risk Analysis',
#  'name': 'Risk Analysis Agent',
#  'preferredTransport': 'JSONRPC',
#  'protocolVersion': '0.3.0',
#  'skills': [],
#  'url': 'https://bedrock-agentcore.us-east-1.amazonaws.com/runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A161615149547%3Aruntime%2Frisk_analysis_assistant-9QOgL4F5WE/invocations/',
#  'version': '0.0.1'}

# %% [markdown]
# #### 3.2 - Test agents
#
# Now, let's invoke the first agent, using A2A:

# %%
import asyncio
import logging
import os
from uuid import uuid4

import httpx
from a2a.client import A2ACardResolver, ClientConfig, ClientFactory
from a2a.types import Message, Part, Role, TextPart

logging.basicConfig(level=logging.ERROR)
logger = logging.getLogger(__name__)

DEFAULT_TIMEOUT = 300  # set request timeout to 5 minutes

def format_agent_response(response):
    """Extract and format agent response for human readability."""
    # Get the main response text from artifacts
    if response.artifacts and len(response.artifacts) > 0:
        artifact = response.artifacts[0]
        if artifact.parts and len(artifact.parts) > 0:
            return artifact.parts[0].root.text
    
    # Fallback: concatenate all agent messages from history
    agent_messages = [
        msg.parts[0].root.text 
        for msg in response.history 
        if msg.role.value == 'agent' and msg.parts
    ]
    return ''.join(agent_messages)


def create_message(*, role: Role = Role.user, text: str) -> Message:
    return Message(
        kind="message",
        role=role,
        parts=[Part(TextPart(kind="text", text=text))],
        message_id=uuid4().hex,
    )

async def send_sync_message(agent_arn, message: str):
    # Get runtime URL from environment variable
    escaped_agent_arn = quote(agent_arn, safe='')

    # Construct the URL
    runtime_url = f"https://bedrock-agentcore.{region}.amazonaws.com/runtimes/{escaped_agent_arn}/invocations/"
    
    # Generate a unique session ID
    session_id = str(uuid4())
    print(f"Generated session ID: {session_id}")

    # Add authentication headers for AgentCore
    headers = {"Authorization": f"Bearer {bearer_token}",
              'X-Amzn-Bedrock-AgentCore-Runtime-Session-Id': session_id}
        
    async with httpx.AsyncClient(timeout=DEFAULT_TIMEOUT, headers=headers) as httpx_client:
        # Get agent card from the runtime URL
        resolver = A2ACardResolver(httpx_client=httpx_client, base_url=runtime_url)
        agent_card = await resolver.get_agent_card()
        print(agent_card)

        # Agent card contains the correct URL (same as runtime_url in this case)
        # No manual override needed - this is the path-based mounting pattern

        # Create client using factory
        config = ClientConfig(
            httpx_client=httpx_client,
            streaming=False,  # Use non-streaming mode for sync response
        )
        factory = ClientFactory(config)
        client = factory.create(agent_card)

        # Create and send message
        msg = create_message(text=message)

        # With streaming=False, this will yield exactly one result
        async for event in client.send_message(msg):
            if isinstance(event, Message):
                logger.info(event.model_dump_json(exclude_none=True, indent=2))
                return event
            elif isinstance(event, tuple) and len(event) == 2:
                # (Task, UpdateEvent) tuple
                task, update_event = event
                logger.info(f"Task: {task.model_dump_json(exclude_none=True, indent=2)}")
                if update_event:
                    logger.info(f"Update: {update_event.model_dump_json(exclude_none=True, indent=2)}")
                return task
            else:
                # Fallback for other response types
                logger.info(f"Response: {str(event)}")
                return event

# %%
def read_pdf(file_path):
    """
    Read and extract text from a PDF file.
    
    Args:
        file_path (str): Path to the PDF file
        
    Returns:
        str: Extracted text from the PDF
    """
    try:
        # Open the PDF file in binary read mode
        with open(file_path, 'rb') as file:
            # Create a PDF reader object
            pdf_reader = PyPDF2.PdfReader(file)
            
            # Get number of pages
            num_pages = len(pdf_reader.pages)
            print(f"Total pages: {num_pages}")
            
            # Extract text from each page
            text = ""
            for page_num in range(num_pages):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()
                
            return text
    
    except FileNotFoundError:
        return "Error: The file was not found."
    except PyPDF2.errors.PdfReadError:
        return "Error: Invalid PDF file or the file is encrypted."
    except Exception as e:
        return f"Error: {str(e)}"

# %%
# Example usage
import PyPDF2
if __name__ == "__main__":
    pdf_path = "data/JoeDoeCreditReport.pdf"  # Replace with your PDF file path
    extracted_JoeDoeCreditReport = read_pdf(pdf_path)
    
    pdf_path = "data/JoeDoeBankStatement.pdf"  # Replace with your PDF file path
    extracted_JoeDoeBankStatement = read_pdf(pdf_path)
    
    pdf_path = "data/JoeDoeBankStatement_2.pdf"  # Replace with your PDF file path
    extracted_JoeDoeBankStatement_2 = read_pdf(pdf_path)
    
    pdf_path = "data/JoeDoePayStub.pdf"  # Replace with your PDF file path
    extracted_JoeDoePayStub = read_pdf(pdf_path)

    pdf_path = "data/JoeDoeIDVerification.pdf"  # Replace with your PDF file path
    extracted_JoeDoeIDVerification = read_pdf(pdf_path)

    pdf_path = "data/JoeDoeTaxes.pdf"  # Replace with your PDF file path
    extracted_JoeDoeTaxes = read_pdf(pdf_path)

    pdf_path = "data/JoeDoeLoanApplication.pdf"  # Replace with your PDF file path
    extracted_JoeDoeLoanApplication = read_pdf(pdf_path)

    pdf_path = "data/JoeDoePropertyInfo.pdf"  # Replace with your PDF file path
    extracted_JoeDoePropertyInfo = read_pdf(pdf_path)
    
    # print("Extracted text:")
    # print(extracted_JoeDoeCreditReport[0:1000])
    # print(extracted_JoeDoeBankStatement[0:1000])
    # print(extracted_JoeDoePayStub[0:1000])
# Out:
# Total pages: 10
# Total pages: 3
# Total pages: 3
# Total pages: 3
# Total pages: 2
# Total pages: 3
# Total pages: 4
# Total pages: 4

# %%
prompt = f"""
            I will give you an Loan Application submission package for Joe Doe. 
            Process each document, and extract require information to process the Loan application. 
            Keep track of the pending or missing documents
            Provide final Approval recomendation.
            Write the insurance policy and provide the final output

            Retrieve information from the application package:
            {extracted_JoeDoeCreditReport} 
            {extracted_JoeDoeBankStatement}
            {extracted_JoeDoeBankStatement_2}
            {extracted_JoeDoePayStub}
            {extracted_JoeDoeIDVerification}
            {extracted_JoeDoeLoanApplication}
            {extracted_JoeDoePropertyInfo}
            {extracted_JoeDoeTaxes}
            """

# %%
result = await send_sync_message(financial_analysis_agent_arn, prompt)
formatted_output = format_agent_response(result)
print(formatted_output)
# Out:
# Generated session ID: fd069b83-81a8-4dea-b488-b342013c53f4
# additional_interfaces=None capabilities=AgentCapabilities(extensions=None, push_notifications=None, state_transition_history=None, streaming=True) default_input_modes=['text'] default_output_modes=['text'] description='An agent to do Financial Analysis.' documentation_url=None icon_url=None name='Financial Analysis Agent' preferred_transport='JSONRPC' protocol_version='0.3.0' provider=None security=None security_schemes=None signatures=None skills=[] supports_authenticated_extended_card=None url='https://bedrock-agentcore.us-east-1.amazonaws.com/runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A161615149547%3Aruntime%2Ffinancial_analysis_assistant-mqZxfd4lJ4/invocations/' version='0.0.1'
# # FINANCIAL ANALYSIS MANAGER - LOAN APPLICATION PROCESSING REPORT
#
# ## Executive Summary
# Processing loan application for **Joe Doe** (SSN: XXX-XX-7845) requesting $420,000 mortgage loan for primary residence purchase.
#
# ---
#
# ## STEP 1: CREDIT ANALYSIS
#
# ### Credit Score Assessment
# - **FICO Score: 705** (Good Range: 670-739)
# - **Score Type:** FICO 8
# - **Report Date:** June 11, 2024
# - **Score Factors Affecting Rating:**
#   1. High revolving balance-to-limit ratio (29%)
#   2. Account establishment length
#   3. Delinquency history
#   4. Recent inquiry activity
#
# ### Credit History Analysis
#
# **Account Summary:**
# - Total Accounts: 12 (9 open, 3 closed)
# - Average Account Age: 8 years, 3 months
# - Oldest Account: 15 years, 2 months
# - Delinquent Accounts: 1
# - Collections: 0
# - Public Records: 0
#
# **Credit Mix Analysis:**
# - Revolving Accounts: 7 (Credit Cards)
# - Installment Accounts: 5 (Student Loans + Auto)
# - Mortgage Accounts: 0
#
# **Credit Utilization:**
# - Total Available Credit: $29,500
# - Current Utilization: $8,637 (29% - HIGH CONCERN)
# - Total Debt: $37,842
#
# **Payment History Red Flags:**
# 1. Chase Sapphire: 30-day late (July 2021)
# 2. Capital One: 30-day late (March 2022)
# 3. Great Lakes Student: 30-day late (September 2013)
# 4. Macy's Store Card: 60-day late (April 2014) - CLOSED
#
# ### Credit Assessment Score: **6.5/10**
# **Concerns:** High utilization ratio, recent late payments within 3 years
#
# ---
#
# ## STEP 2: INCOME VERIFICATION
#
# ### Employment Verification
# **Current Employment:**
# - **Company:** Ocktank (ML Engineer)
# - **Monthly Gross:** $8,460 (based on paystub)
# - **Annual Gross:** $101,520 (YTD basis)
# - **Position:** Stable engineering role
#
# **⚠️ DISCREPANCY ALERT:**
# - Application states employer: "TechCorp Solutions Inc." ($102,000 annually)
# - Paystub shows employer: "Ocktank" ($101,520 YTD)
# - **Action Required:** Verification needed
#
# ### Income Source Analysis
# **Paystub Analysis (June-July 2024):**
# - Gross Pay (2 months): $16,920
# - Net Pay (2 months): $11,031.62
# - Deduction Rate: 34.8%
# - Overtime Income: $1,080 (shows additional earning capacity)
#
# ### Asset Verification
#
# **Bank Account Analysis:**
#
# **Bank of America Statement (June-July 2024):**
# - Beginning Balance: $2,847.32
# - Ending Balance: $4,110.54
# - Regular Direct Deposits: $2,100 bi-weekly
# - Monthly Expenses: ~$2,000
#
# **First National Bank Statement (May-June 2024):**
# - Beginning Balance: $2,450.75
# - Ending Balance: $2,800.50
# - Regular Direct Deposits: $2,100 bi-weekly
#
# **⚠️ ASSET VERIFICATION ISSUES:**
# 1. **Application Claims vs. Statements:**
#    - Claimed Checking: $25,000
#    - Actual Checking (BOA): $4,110.54
#    - Claimed Savings: $85,000
#    - **MAJOR DISCREPANCY - VERIFICATION REQUIRED**
#
# 2. **Missing Documentation:**
#    - Savings account statements
#    - Investment account statements
#    - 401(k) statements
#
# ---
#
# ## DOCUMENT TRACKING STATUS
#
# ### ✅ RECEIVED DOCUMENTS:
# 1. Credit Report (Complete)
# 2. Loan Application Form (Complete)
# 3. Employment Paystub (Complete)
# 4. Bank Statements - 2 accounts (Partial)
# 5. Property Appraisal Report (Complete)
# 6. Tax Return 2023 (Complete - but different SSN)
# 7. Government ID (Complete)
#
# ### ❌ PENDING/MISSING DOCUMENTS:
# 1. **CRITICAL:** Savings account statements verification
# 2. **CRITICAL:** Investment account statements ($40,000 claimed)
# 3. **CRITICAL:** 401(k) statements ($75,000 claimed)
# 4. Employment verification letter from current employer
# 5. Recent pay stubs (additional 2-3 months)
# 6. Bank statements for claimed $25,000 checking account
# 7. Down payment source documentation
#
# ### 🔍 VERIFICATION REQUIRED:
# 1. **Employment discrepancy** (TechCorp vs. Ocktank)
# 2. **Asset verification** (claimed vs. actual balances)
# 3. **SSN consistency** (Tax return shows different SSN)
#
# ---
#
# ## DEBT-TO-INCOME ANALYSIS
#
# **Monthly Income:** $8,460 (verified)
# **Existing Monthly Obligations:**
# - Student Loans: $500 ($180 + $110 + $210)
# - Auto Loan: $415
# - Credit Cards: ~$200 (estimated minimum payments)
# - Current Rent: $1,200
# - **Total Existing DTI:** $2,315 (27%)
#
# **Proposed Mortgage Payment:** ~$2,100/month
# **New Total DTI:** ~52% (**EXCEEDS 43% GUIDELINE**)
#
# ---
#
# ## RISK ASSESSMENT
#
# ### HIGH RISK FACTORS:
# 1. **Asset Verification Failure** - Cannot substantiate down payment
# 2. **Employment Discrepancy** - Requires immediate clarification
# 3. **High DTI Ratio** - 52% exceeds lending guidelines
# 4. **Credit Utilization** - 29% is concerning
# 5. **Recent Late Payments** - Within 3-year period
#
# ### MODERATE RISK FACTORS:
# 1. Credit Score of 705 (acceptable but not optimal)
# 2. Limited mortgage payment history
# 3. High revolving debt balances
#
# ---
#
# ## PRELIMINARY RECOMMENDATION
#
# ### ❌ **CONDITIONAL DECLINE**
#
# **Primary Reasons:**
# 1. **Critical asset verification failure**
# 2. **DTI ratio exceeds guidelines (52% vs. 43% max)**
# 3. **Employment documentation discrepancies**
# 4. **Insufficient down payment verification**
#
# ### CONDITIONS FOR RECONSIDERATION:
# 1. Provide complete asset documentation proving $105,000 down payment
# 2. Resolve employment verification discrepancy
# 3. Reduce existing debt to achieve <43% DTI
# 4. Provide additional 3 months of bank statements
# 5. Employment verification letter from current employer
#
# ---
#
# ## INSURANCE POLICY RECOMMENDATION
#
# *Note: Insurance policy would only be written upon loan approval. Given current decline recommendation, policy writing is premature.*
#
# **If loan were approved, recommended coverage:**
# - Property Value: $525,000
# - Coverage Amount: $420,000+ (replacement cost)
# - Deductible: $1,000-$2,500
# - Annual Premium Estimate: $1,200-$1,500
#
# ---
#
# ## NEXT STEPS
#
# 1. **IMMEDIATE:** Request complete asset documentation
# 2. **IMMEDIATE:** Clarify employment verification
# 3. **PRIORITY:** Debt reduction plan to meet DTI requirements
# 4. **FOLLOW-UP:** Schedule re-evaluation upon document completion
#
# **Application Status:** **PENDING - ADDITIONAL DOCUMENTATION REQUIRED**
#
# ---
#
# *Report prepared by: Financial Analysis Manager*
# *Date: [Current Date]*
# *Application ID: LA-2023-11-001234*

# %% [markdown]
# Not, let's test our 2nd agent:

# %%
result = await send_sync_message(blog_agent_arn, prompt)
formatted_output = format_agent_response(result)
print(formatted_output)
# Out:
# Generated session ID: 873e29ff-e8f0-4d92-83c8-bfb8e36754b0
# additional_interfaces=None capabilities=AgentCapabilities(extensions=None, push_notifications=None, state_transition_history=None, streaming=True) default_input_modes=['text'] default_output_modes=['text'] description='An agent to do Risk Analysis' documentation_url=None icon_url=None name='Risk Analysis Agent' preferred_transport='JSONRPC' protocol_version='0.3.0' provider=None security=None security_schemes=None signatures=None skills=[] supports_authenticated_extended_card=None url='https://bedrock-agentcore.us-east-1.amazonaws.com/runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A161615149547%3Aruntime%2Frisk_analysis_assistant-9QOgL4F5WE/invocations/' version='0.0.1'
# # LOAN APPLICATION RISK ANALYSIS REPORT
#
# **Applicant:** Joe Doe
# **Application Number:** LA-2023-11-001234
# **Analysis Date:** January 15, 2025
# **Risk Analysis Manager:** AI Risk Assessment System
#
# ---
#
# ## STEP 1: RISK CALCULATION ANALYSIS
#
# ### Credit Risk Assessment
#
# **FICO Score Analysis:**
# - Current Score: 705 (Good range)
# - Score Factors: High credit utilization (29%), limited account age, recent delinquencies
# - Probability of Default (PD): **8.2%** (Moderate Risk)
#
# **Income Verification:**
# - Paystub Income: $101,520 annually (consistent with application)
# - Application Income: $102,000 annually
# - **Variance:** 0.47% (ACCEPTABLE)
#
# **Debt-to-Income Calculation:**
# - Monthly Gross Income: $8,460
# - Total Monthly Debt Obligations: $2,300 + $3,040 (proposed mortgage) = $5,340
# - **DTI Ratio: 63.1%** (HIGH RISK - Exceeds 43% standard)
#
# **Loss Given Default (LGD):** 25% (secured by property)
# **Exposure at Default (EAD):** $420,000
#
# ### Market Risk Factors
# - Property market stable in Springfield, IL
# - Interest rate environment: Moderate risk
# - Economic indicators: Stable employment sector
#
# ### Concentration Risk
# - Single income source
# - No mortgage diversification
# - High loan amount relative to property value
#
# ---
#
# ## STEP 2: FRAUD DETECTION ANALYSIS
#
# ### Document Inconsistency Alerts
#
# 🚨 **CRITICAL DISCREPANCIES IDENTIFIED:**
#
# 1. **Address Inconsistencies:**
#    - Loan Application: 123 Maple Street, Apt 2B, Springfield, IL
#    - Credit Report: 2834 Maple Avenue, Apt 5B, Portland, OR
#    - Bank Statements: Multiple transaction patterns suggest Portland residence
#    - **FRAUD RISK: HIGH**
#
# 2. **Income Discrepancies:**
#    - Application Claims: TechCorp Solutions, $102,000/year
#    - Paystub Shows: Ocktank, ML Engineer, $101,520/year
#    - **FRAUD RISK: MODERATE**
#
# 3. **Identity Verification Issues:**
#    - Government ID: Testlandia Republic (Invalid jurisdiction)
#    - SSN Patterns: Multiple variations across documents
#    - **FRAUD RISK: CRITICAL**
#
# 4. **Employment Verification:**
#    - Application: 5 years at TechCorp
#    - Paystub: Different company entirely (Ocktank)
#    - **FRAUD RISK: HIGH**
#
# 5. **Property Concerns:**
#    - Requested property: 789 Oak Ridge Lane ($525,000)
#    - Appraised property: 1247 Maple Grove Lane ($385,000)
#    - **FRAUD RISK: CRITICAL**
#
# ### Synthetic Identity Indicators
# - Multiple address variations
# - Inconsistent employer information
# - Invalid government identification
# - **Synthetic Identity Score: 85/100 (HIGH RISK)**
#
# ---
#
# ## MISSING DOCUMENTS CHECKLIST
#
# ❌ **PENDING ITEMS:**
# 1. Valid Government-issued Photo ID
# 2. Employment verification letter
# 3. Property purchase agreement
# 4. Title insurance commitment
# 5. Home inspection report
# 6. Proof of down payment funds
# 7. Current property tax assessment
#
# ---
#
# ## FINAL RECOMMENDATION
#
# ### ❌ **APPLICATION DENIED**
#
# **Primary Reasons for Denial:**
#
# 1. **Fraudulent Documentation** - Multiple critical inconsistencies across all submitted documents
# 2. **Identity Verification Failure** - Invalid government ID from fictional jurisdiction
# 3. **Excessive DTI Ratio** - 63.1% exceeds acceptable lending standards
# 4. **Synthetic Identity Suspected** - High fraud score indicating potential synthetic identity fraud
# 5. **Property Mismatch** - Requested vs. appraised properties don't match
#
# **Risk Score: 92/100 (EXTREME RISK)**
#
# ---
#
# ## REQUIRED ACTIONS
#
# 1. **Immediate Escalation** to Fraud Investigation Unit
# 2. **Report to Credit Bureaus** - Potential identity theft
# 3. **File Suspicious Activity Report** (SAR)
# 4. **Preserve All Documentation** for investigation
# 5. **No Further Processing** until identity verified through legitimate channels
#
# ---
#
# ## INSURANCE POLICY
#
# **Due to the high fraud risk and application denial, no insurance policy can be written at this time.**
#
# **Recommended Actions:**
# - Applicant must provide legitimate, verifiable documentation
# - Complete identity verification through authorized government agencies
# - Resubmit application with consistent, verified information
#
# ---
#
# **Report Generated By:** AI Risk Analysis System
# **Confidence Level:** 99.2%
# **Review Status:** Requires Human Fraud Specialist Review
# **Next Action:** Forward to Compliance Department
#
# **⚠️ WARNING: This application exhibits multiple indicators of fraudulent activity and should not be processed further without complete investigation.**

# %% [markdown]
# Following is a more detailed output, showing steps that agent has taken.
#
# Feel free to change the questions asked to agent and see the step-by-step result.

# %%
def format_agent_trace(response):
    """Format agent response as a readable trace of calls."""
    print("=" * 60)
    print("🔍 AGENT EXECUTION TRACE")
    print("=" * 60)
    
    # Context info
    print(f"📋 Context ID: {response.context_id}")
    print(f"🆔 Task ID: {response.id}")
    print(f"📊 Status: {response.status.state.value}")
    print(f"⏰ Completed: {response.status.timestamp}")
    print()
    
    # Trace through history
    print("🔄 EXECUTION FLOW:")
    print("-" * 40)
    
    for i, msg in enumerate(response.history, 1):
        role_icon = "👤" if msg.role.value == "user" else "🤖"
        text = msg.parts[0].root.text if msg.parts else "[No content]"
        
        # Truncate long messages for trace view
        if len(text) > 80:
            text = text[:77] + "..."
            
        print(f"{i:2d}. {role_icon} {msg.role.value.upper()}: {text}")
    
    print()
    print("✅ FINAL RESULT:")
    print("-" * 40)
    
    # Final artifact
    if response.artifacts:
        final_text = response.artifacts[0].parts[0].root.text
        print(final_text[:200] + "..." if len(final_text) > 200 else final_text)
    
    print("=" * 60)

# %%
format_agent_trace(result)
# Out:
# ============================================================
# 🔍 AGENT EXECUTION TRACE
# ============================================================
# 📋 Context ID: b7269469-29cd-4eea-ac52-1d0a07617863
# 🆔 Task ID: 2e1b9ae7-ea0a-4df7-b764-bc45c4574748
# 📊 Status: completed
# ⏰ Completed: 2025-11-25T02:20:45.393717+00:00
#
# 🔄 EXECUTION FLOW:
# ----------------------------------------
#  1. 👤 USER:
#             I will give you an Loan Application submission package for Joe D...
#  2. 🤖 AGENT: #
#  3. 🤖 AGENT:  LOAN APPLICATION
#  4. 🤖 AGENT:  RISK ANALYSIS REPORT
#
# **Applic
#  5. 🤖 AGENT: ant:** Joe Doe
#  6. 🤖 AGENT:
# **Application Number:** LA
#  7. 🤖 AGENT: -2023-11
#  8. 🤖 AGENT: -001234
# **Analysis
#  9. 🤖 AGENT:  Date:** January 15, 2
# 10. 🤖 AGENT: 025
# **Risk
# 11. 🤖 AGENT:  Analysis Manager:** AI Risk
# 12. 🤖 AGENT:  Assessment System
#
# ---
#
# ## STEP
# 13. 🤖 AGENT:  1: RISK
# 14. 🤖 AGENT:  CALCULATION ANALYSIS
#
# ### Credit
# 15. 🤖 AGENT:  Risk Assessment
#
# **
# 16. 🤖 AGENT: FICO Score Analysis
# 17. 🤖 AGENT: :**
# - Current Score
# 18. 🤖 AGENT: : 705
# 19. 🤖 AGENT:  (Good range)
# - Score
# 20. 🤖 AGENT:  Factors: High credit utilization (29
# 21. 🤖 AGENT: %), limited account age
# 22. 🤖 AGENT: , recent de
# 23. 🤖 AGENT: linquencies
# -
# 24. 🤖 AGENT:  Probability of Default (PD): **
# 25. 🤖 AGENT: 8.2%** (
# 26. 🤖 AGENT: Moderate Risk)
#
# **Income
# 27. 🤖 AGENT:  Verification:**
# -
# 28. 🤖 AGENT:  Paystub Income
# 29. 🤖 AGENT: : $101,520
# 30. 🤖 AGENT:  annually
# 31. 🤖 AGENT:  (
# 32. 🤖 AGENT: consistent
# 33. 🤖 AGENT:  with
# 34. 🤖 AGENT:  application
# 35. 🤖 AGENT: )
# - Application
# 36. 🤖 AGENT:  Income: $102
# 37. 🤖 AGENT: ,000 annually
# 38. 🤖 AGENT:
# - **
# 39. 🤖 AGENT: Variance
# 40. 🤖 AGENT: :**
# 41. 🤖 AGENT: 0.47
# 42. 🤖 AGENT: % (
# 43. 🤖 AGENT: ACCEPTABLE)
#
# **
# 44. 🤖 AGENT: Debt-to-
# 45. 🤖 AGENT: Income Calculation
# 46. 🤖 AGENT: :**
# - Monthly
# 47. 🤖 AGENT:  Gross Income: $8
# 48. 🤖 AGENT: ,460
# - Total
# 49. 🤖 AGENT:  Monthly Debt
# 50. 🤖 AGENT:  Obligations: $2
# 51. 🤖 AGENT: ,300
# 52. 🤖 AGENT: + $3,040
# 53. 🤖 AGENT:  (propose
# 54. 🤖 AGENT: d mortgage) = $5,340
# 55. 🤖 AGENT:
# - **DTI Ratio:
# 56. 🤖 AGENT:  63
# 57. 🤖 AGENT: .1%** (HIGH
# 58. 🤖 AGENT:  RISK -
# 59. 🤖 AGENT:  Exce
# 60. 🤖 AGENT: eds 43% standar
# 61. 🤖 AGENT: d)
#
# **Loss
# 62. 🤖 AGENT:  Given Default (LGD
# 63. 🤖 AGENT: ):** 25
# 64. 🤖 AGENT: % (secured by
# 65. 🤖 AGENT:  property)
# 66. 🤖 AGENT:
# **Exposure at Default (
# 67. 🤖 AGENT: EAD):** $420
# 68. 🤖 AGENT: ,000
#
# ### Market Risk
# 69. 🤖 AGENT:  Factors
# - Property
# 70. 🤖 AGENT:  market stable in
# 71. 🤖 AGENT:  Springfield, IL
# - Interest
# 72. 🤖 AGENT:  rate environment:
# 73. 🤖 AGENT:  Moderate
# 74. 🤖 AGENT:  risk
# - Economic
# 75. 🤖 AGENT:  indicators: Stable employment
# 76. 🤖 AGENT:  sector
#
# ### Concentration
# 77. 🤖 AGENT:  Risk
# - Single
# 78. 🤖 AGENT:  income source
# 79. 🤖 AGENT:
# - No mortgage divers
# 80. 🤖 AGENT: ification
# - High
# 81. 🤖 AGENT:  loan amount relative
# 82. 🤖 AGENT:  to property value
#
# ---
#
# ##
# 83. 🤖 AGENT:  STEP 2:
# 84. 🤖 AGENT:  FRAUD DETECTION
# 85. 🤖 AGENT:  ANALYSIS
#
# ### Document
# 86. 🤖 AGENT:  Inconsistency
# 87. 🤖 AGENT:  Alerts
# 88. 🤖 AGENT:
#
# 🚨 **
# 89. 🤖 AGENT: CRITICAL DISCREPANCIES
# 90. 🤖 AGENT:  IDENTIFIED:**
#
# 1. **
# 91. 🤖 AGENT: Address Incons
# 92. 🤖 AGENT: istencies:**
#    -
# 93. 🤖 AGENT:  Loan Application: 123
# 94. 🤖 AGENT: Maple Street,
# 95. 🤖 AGENT:  Apt 2
# 96. 🤖 AGENT: B, Springfield, IL
# 97. 🤖 AGENT:
#    - Credit
# 98. 🤖 AGENT:  Report: 2834
# 99. 🤖 AGENT:  Maple Avenue
# 100. 🤖 AGENT: , Apt
# 101. 🤖 AGENT:  5
# 102. 🤖 AGENT: B, Portlan
# 103. 🤖 AGENT: d, OR
#    -
# 104. 🤖 AGENT:  Bank Statements: Multiple
# 105. 🤖 AGENT:  transaction patterns
# 106. 🤖 AGENT:  suggest Portland residence
# 107. 🤖 AGENT:
#    - **
# 108. 🤖 AGENT: FRAUD RISK: HIGH
# 109. 🤖 AGENT: **
#
# 2. **
# 110. 🤖 AGENT: Income Discrepancies
# 111. 🤖 AGENT: :**
#    - Application
# 112. 🤖 AGENT:  Claims: T
# 113. 🤖 AGENT: echC
# 114. 🤖 AGENT: orp Solutions, $102
# 115. 🤖 AGENT: ,000/year
#    -
# 116. 🤖 AGENT:  Paystub Shows:
# 117. 🤖 AGENT:  Ockt
# 118. 🤖 AGENT: ank, ML
# 119. 🤖 AGENT:  Engineer, $101,520
# 120. 🤖 AGENT: /year
#    -
# 121. 🤖 AGENT:  **FRAUD RISK
# 122. 🤖 AGENT: : MODERATE**
#
# 3.
# 123. 🤖 AGENT:  **Identity Verification Issues:**
# 124. 🤖 AGENT:
#    - Government ID
# 125. 🤖 AGENT: : Test
# 126. 🤖 AGENT: landia Republic (Invali
# 127. 🤖 AGENT: d jurisdiction)
#    - SS
# 128. 🤖 AGENT: N Patterns
# 129. 🤖 AGENT: : Multiple variations across
# 130. 🤖 AGENT:  documents
#    - **
# 131. 🤖 AGENT: FRAUD RISK:
# 132. 🤖 AGENT:  CRITICAL**
#
# 4
# 133. 🤖 AGENT: . **Employment
# 134. 🤖 AGENT:  Verification:**
#
# 135. 🤖 AGENT: - Application: 5
# 136. 🤖 AGENT:  years at Tech
# 137. 🤖 AGENT: Corp
#    -
# 138. 🤖 AGENT:  Paystub: Different
# 139. 🤖 AGENT:  company entirely (
# 140. 🤖 AGENT: Ocktank)
# 141. 🤖 AGENT:
#    - **
# 142. 🤖 AGENT: FRAUD RISK: HIGH
# 143. 🤖 AGENT: **
#
# 5. **Property Concerns
# 144. 🤖 AGENT: :**
#    -
# 145. 🤖 AGENT:  Requested property
# 146. 🤖 AGENT: : 789
# 147. 🤖 AGENT:  Oak Ridge
# 148. 🤖 AGENT:  Lane ($525
# 149. 🤖 AGENT: ,000)
#
# 150. 🤖 AGENT: - Appraised property
# 151. 🤖 AGENT: : 1
# 152. 🤖 AGENT: 247 Maple
# 153. 🤖 AGENT:  Grove Lane ($385
# 154. 🤖 AGENT: ,000)
#
# 155. 🤖 AGENT: - **FRAUD
# 156. 🤖 AGENT:  RISK: CRITICAL
# 157. 🤖 AGENT: **
#
# ### Synthetic
# 158. 🤖 AGENT:  Identity Indicators
# 159. 🤖 AGENT:
# - Multiple address variations
# - Incons
# 160. 🤖 AGENT: istent employer information
# 161. 🤖 AGENT:
# - Invali
# 162. 🤖 AGENT: d government identification
# - **
# 163. 🤖 AGENT: Synthetic Identity Score: 85
# 164. 🤖 AGENT: /100 (HIGH RISK)**
# 165. 🤖 AGENT:
#
# ---
#
# ## MISSING
# 166. 🤖 AGENT:  DOCUMENTS CHEC
# 167. 🤖 AGENT: KLIST
#
# ❌ **PENDING
# 168. 🤖 AGENT:  ITEMS:**
# 1
# 169. 🤖 AGENT: . Vali
# 170. 🤖 AGENT: d Government-issue
# 171. 🤖 AGENT: d Photo ID
# 2. Employment
# 172. 🤖 AGENT:  verification letter
# 3. Property
# 173. 🤖 AGENT:  purchase agreement
# 4. Title
# 174. 🤖 AGENT:  insurance commitment
# 175. 🤖 AGENT:
# 5. Home
# 176. 🤖 AGENT:  inspection report
# 6.
# 177. 🤖 AGENT:  Proof of down payment funds
# 178. 🤖 AGENT:
# 7. Current
# 179. 🤖 AGENT:  property tax assessment
# 180. 🤖 AGENT:
#
# ---
# 181. 🤖 AGENT:
#
# ## FINAL
# 182. 🤖 AGENT:  RECOMMENDATION
#
# ###
# 183. 🤖 AGENT: ❌ **APPLICATION
# 184. 🤖 AGENT:  DENIED**
# 185. 🤖 AGENT:
#
# **Primary Reasons for
# 186. 🤖 AGENT:  Denial:**
#
# 1. **
# 187. 🤖 AGENT: Fraudulent Documentation** - Multiple critical
# 188. 🤖 AGENT:  inconsistencies across
# 189. 🤖 AGENT:  all submitted documents
# 2. **
# 190. 🤖 AGENT: Identity Verification Failure**
# 191. 🤖 AGENT:  - Invalid government ID from
# 192. 🤖 AGENT:  fictional jurisdiction
# 3. **
# 193. 🤖 AGENT: Excessive DTI Ratio** -
# 194. 🤖 AGENT:  63.1%
# 195. 🤖 AGENT:  exceeds acceptable lending
# 196. 🤖 AGENT:  standards
# 4. **
# 197. 🤖 AGENT: Synthetic Identity Suspected** - High frau
# 198. 🤖 AGENT: d score indicating potential
# 199. 🤖 AGENT:  synthetic identity fraud
# 5. **Property
# 200. 🤖 AGENT:  Mismatch** -
# 201. 🤖 AGENT:  Requested vs. appraised properties
# 202. 🤖 AGENT:  don't match
#
# **
# 203. 🤖 AGENT: Risk Score: 92
# 204. 🤖 AGENT: /100 (EXTREME
# 205. 🤖 AGENT:  RISK)**
#
# ---
#
# ## REQUIRED
# 206. 🤖 AGENT:  ACTIONS
#
# 1. **Immediate
# 207. 🤖 AGENT:  Escalation** to
# 208. 🤖 AGENT:  Fraud Investigation Unit
# 2. **Report
# 209. 🤖 AGENT:  to Credit Bureaus** -
# 210. 🤖 AGENT:  Potential identity theft
# 3. **
# 211. 🤖 AGENT: File Suspicious Activity Report** (
# 212. 🤖 AGENT: SAR)
# 4. **Preserve
# 213. 🤖 AGENT:  All Documentation** for investigation
# 214. 🤖 AGENT:
# 5. **No
# 215. 🤖 AGENT:  Further Processing** until identity
# 216. 🤖 AGENT:  verified through legitimate
# 217. 🤖 AGENT:  channels
#
# ---
#
# ##
# 218. 🤖 AGENT:  INSURANCE POLICY
# 219. 🤖 AGENT:
#
# **Due
# 220. 🤖 AGENT:  to the high frau
# 221. 🤖 AGENT: d risk and application
# 222. 🤖 AGENT:  denial, no
# 223. 🤖 AGENT:  insurance policy can be written at this time.**
# 224. 🤖 AGENT:
#
# **Recommended Actions
# 225. 🤖 AGENT: :**
# - Applic
# 226. 🤖 AGENT: ant must provide legitimate,
# 227. 🤖 AGENT:  verifiable documentation
# - Complete
# 228. 🤖 AGENT:  identity verification through
# 229. 🤖 AGENT:  authorized government agencies
# 230. 🤖 AGENT:
# - Re
# 231. 🤖 AGENT: submit application with
# 232. 🤖 AGENT:  consistent, verified information
# 233. 🤖 AGENT:
#
# ---
#
# **Report Generate
# 234. 🤖 AGENT: d By:** AI Risk Analysis
# 235. 🤖 AGENT:  System
# **Confidence
# 236. 🤖 AGENT:  Level:** 99
# 237. 🤖 AGENT: .2
# 238. 🤖 AGENT: %
# **Review
# 239. 🤖 AGENT:  Status:** Requires
# 240. 🤖 AGENT:  Human Frau
# 241. 🤖 AGENT: d Specialist Review
# 242. 🤖 AGENT:
# **Next Action:** Forwar
# 243. 🤖 AGENT: d to Compliance Department
# 244. 🤖 AGENT:
#
# **⚠️ WARNING
# 245. 🤖 AGENT: : This application
# 246. 🤖 AGENT:  exhibits multiple indicators
# 247. 🤖 AGENT:  of fraudulent activity and shoul
# 248. 🤖 AGENT: d not be processed further without complete
# 249. 🤖 AGENT:  investigation.**
#
# ✅ FINAL RESULT:
# ----------------------------------------
# # LOAN APPLICATION RISK ANALYSIS REPORT
#
# **Applicant:** Joe Doe
# **Application Number:** LA-2023-11-001234
# **Analysis Date:** January 15, 2025
# **Risk Analysis Manager:** AI Risk Assessment System...
# ============================================================

# %% [markdown]
# Congratulations, you have deployed your first agent, using A2A protocol on Amazon AgentCore Runtime!
#
# Now, let's move to next lab.
