# %% [markdown]
# ## Setting up Orchestrator Agent A2A
#
# In the previous module, we've launched two agents, using AgentCore Runtime, that supports A2A invocations.
#
# In this lab, we're going to add an orchestrator, that will invoke our sub-agents.
#
# <img src="images/architecture.png" style="width: 80%;">
#
# So let's get started!

# %% [markdown]
# ### Setup
#
# Import required dependencies

# %%
# Import libraries
import os
import json
import requests
import boto3
from boto3.session import Session
from strands.tools import tool

# Get boto session
boto_session = Session()
region = boto_session.region_name

# %% [markdown]
# Retrieve information from previous LABs, so we can use it during this one.

# %%
# %store -r

# %% [markdown]
# ### 1 - Create Code for the orchestrator agent
#
# Let's generate Python code that will be used for our orchestrator, and lately will be deployed in AgentCore.

# %%
# %%writefile agents/orchestrator.py
import logging
import json
import asyncio
from typing import Dict, Optional
from urllib.parse import quote
from uuid import uuid4

import httpx
from a2a.client import A2ACardResolver, ClientConfig, ClientFactory
from a2a.types import Message, Part, Role, TextPart

from helpers.utils import get_cognito_secret, reauthenticate_user, get_ssm_parameter, SSM_DOCS_AGENT_ARN, SSM_BLOGS_AGENT_ARN

from strands import Agent, tool
from bedrock_agentcore.runtime import BedrockAgentCoreApp
from fastapi import HTTPException

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Reduced timeouts to prevent hanging
DEFAULT_TIMEOUT = 15  # 15s instead of 300s
AGENT_TIMEOUT = 10    # 10s per agent call

# Global cache and connection pool
_cache = {
    'cognito_config': None,
    'agent_arns': {},
    'agent_cards': {},
    'http_client': None
}

app = BedrockAgentCoreApp()

def get_cached_config():
    """Cache all expensive operations"""
    if not _cache['agent_arns']:
        _cache['agent_arns'] = {
            'docs': get_ssm_parameter(SSM_DOCS_AGENT_ARN),
            'blogs': get_ssm_parameter(SSM_BLOGS_AGENT_ARN)
        }
    
    if not _cache['cognito_config']:
        secret = json.loads(get_cognito_secret())
        _cache['cognito_config'] = {
            'client_id': secret.get("client_id"),
            'client_secret': secret.get("client_secret")
        }
    
    return _cache['agent_arns'], _cache['cognito_config']

def get_bearer_token():
    """Generate fresh bearer token for each request"""
    _, config = get_cached_config()
    return reauthenticate_user(
        config['client_id'], 
        config['client_secret']
    )

def get_http_client():
    """Reuse HTTP client with aggressive timeouts"""
    if not _cache['http_client']:
        _cache['http_client'] = httpx.AsyncClient(
            timeout=httpx.Timeout(DEFAULT_TIMEOUT, connect=5.0),
            limits=httpx.Limits(max_keepalive_connections=5, max_connections=10),
            http2=True  # Enable HTTP/2 for better performance
        )
    return _cache['http_client']

def create_message(text: str) -> Message:
    return Message(
        kind="message",
        role=Role.user,
        parts=[Part(TextPart(kind="text", text=text))],
        message_id=uuid4().hex,
    )

async def send_agent_message(message: str, agent_type: str) -> Optional[str]:
    """Optimized agent communication with circuit breaker pattern"""
    try:
        agent_arns, _ = get_cached_config()
        agent_arn = agent_arns[agent_type]
        bearer_token = get_bearer_token()
        
        from boto3.session import Session
        region = Session().region_name
        
        escaped_arn = quote(agent_arn, safe='')
        runtime_url = f"https://bedrock-agentcore.{region}.amazonaws.com/runtimes/{escaped_arn}/invocations/"
        
        headers = {
            "Authorization": f"Bearer {bearer_token}",
            'X-Amzn-Bedrock-AgentCore-Runtime-Session-Id': str(uuid4())
        }
        
        httpx_client = get_http_client()
        httpx_client.headers.update(headers)
        
        # Cache agent card
        if agent_arn not in _cache['agent_cards']:
            resolver = A2ACardResolver(httpx_client=httpx_client, base_url=runtime_url)
            _cache['agent_cards'][agent_arn] = await asyncio.wait_for(
                resolver.get_agent_card(), timeout=5.0
            )
        
        agent_card = _cache['agent_cards'][agent_arn]
        
        # Create client with non-streaming mode
        config = ClientConfig(httpx_client=httpx_client, streaming=False)
        factory = ClientFactory(config)
        client = factory.create(agent_card)
        
        msg = create_message(message)
        
        # Use timeout for the entire operation
        async with asyncio.timeout(AGENT_TIMEOUT):
            async for event in client.send_message(msg):
                if isinstance(event, Message):
                    return event.parts[0].text if event.parts else "No response"
                elif isinstance(event, tuple) and len(event) == 2:
                    return event[0].parts[0].text if event[0].parts else "No response"
        
        return "Timeout: No response received"
        
    except asyncio.TimeoutError:
        logger.warning(f"Timeout calling {agent_type} agent")
        return f"Agent {agent_type} timed out"
    except Exception as e:
        logger.error(f"Error calling {agent_type}: {e}")
        return f"Error: {str(e)[:100]}"

@tool
async def send_mcp_message(message: str):
    """Send message to AWS Docs agent with timeout"""
    return await send_agent_message(f"Summarize briefly: {message}", 'docs')

@tool
async def send_blog_message(message: str):
    """Send message to AWS Blogs agent with timeout"""
    return await send_agent_message(f"Summarize briefly: {message}", 'blogs')


system_prompt = """You are an AWS information orchestrator. 

Available agents:
- AWS Documentation: Technical AWS service details
- AWS Blogs: Latest AWS news and announcements

IMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.

Guidelines:
- Use parallel queries when possible
- Timeout after 10 seconds per agent
- Provide quick, actionable answers
- If agents timeout, provide what you know
"""

agent = Agent(
    system_prompt=system_prompt, 
    tools=[send_mcp_message, send_blog_message],
    name="AWS Orchestration Agent",
    description="An agent to orchestrate sub-agents"
)

@app.entrypoint
async def invoke_agent(payload, context):
    logger.info("Fast orchestrator processing request")
    
    try:
        user_prompt = payload.get("prompt", "")
        if not user_prompt:
            raise HTTPException(status_code=400, detail="No prompt provided")

        logger.info(f"Query: {user_prompt[:100]}...")
        
        # Set overall timeout for the entire operation
        async with asyncio.timeout(25.0):  # Max 25s total
            agent_stream = agent.stream_async(user_prompt)
            
            async for event in agent_stream:
                yield event

    except asyncio.TimeoutError:
        logger.error("Overall operation timed out")
        yield {"error": "Request timed out after 25 seconds"}
    except HTTPException:
        raise
    except Exception as e:
        logger.error(f"Processing failed: {e}")
        yield {"error": f"Processing failed: {str(e)[:100]}"}

# Cleanup on shutdown
async def cleanup():
    if _cache['http_client']:
        await _cache['http_client'].aclose()

if __name__ == "__main__":
    import atexit
    atexit.register(lambda: asyncio.run(cleanup()))
    app.run()
# Out:
# Overwriting agents/orchestrator.py

# %% [markdown]
# #### 1.1 - Create IAM Role for the Agent

# %%
from helpers.utils import create_agentcore_runtime_execution_role, ORCHESTRATOR_ROLE_NAME

agent_name="aws_orchestrator_assistant"

execution_role_arn = create_agentcore_runtime_execution_role(ORCHESTRATOR_ROLE_NAME)
# Out:
# ℹ️ Role AWSOrchestratorAssistantAgentCoreRole-us-east-1 already exists
# Role ARN: arn:aws:iam::161615149547:role/AWSOrchestratorAssistantAgentCoreRole-us-east-1

# %% [markdown]
# ### 2 - Deploy to AgentCore Runtime
#
# Now, let's deploy the orchestrator in the AgentCore Runtime.
#
# Note that in this example, we're not adding `protocol` parameter. Which means that this will be a HTTP agent.

# %%
from bedrock_agentcore_starter_toolkit import Runtime

agentcore_runtime = Runtime()

# Configure the deployment
response = agentcore_runtime.configure(
    entrypoint="agents/orchestrator.py",
    execution_role=execution_role_arn,
    auto_create_ecr=True,
    requirements_file="agents/requirements.txt",
    region=region,
    agent_name=agent_name,
    authorizer_configuration={
        "customJWTAuthorizer": {
            "allowedClients": [COGNITO_CLIENT_ID],
            "discoveryUrl": DISCOVERY_URL,
        }
    },
)

print("Configuration completed:", response)
# Out:
# Entrypoint parsed: file=/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/agents/orchestrator.py, bedrock_agentcore_name=orchestrator
# Memory configured with STM only
# Configuring BedrockAgentCore agent: aws_orchestrator_assistant
# 💡 No container engine found (Docker/Finch/Podman not installed)
# ✓ Default deployment uses CodeBuild (no container engine needed), For local builds, install Docker, Finch, or
# Podman
# Will create new memory with mode: STM_ONLY
# Memory configuration: Short-term memory only
# Found existing memory ID from previous launch: aws_orchestrator_assistant_mem-qhOp4oEGM3
# ⚠️ Platform mismatch: Current system is 'linux/amd64' but Bedrock AgentCore requires 'linux/arm64', so local builds
# won't work.
# Please use default launch command which will do a remote cross-platform build using code build.For deployment other
# options and workarounds, see:
# https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/getting-started-custom.html
# Generated Dockerfile: Dockerfile
# Generated .dockerignore: /home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.dockerignore
# Keeping 'aws_orchestrator_assistant' as default agent
# Bedrock AgentCore configured: /home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.bedrock_agentcore.yaml
# Configuration completed: config_path=PosixPath('/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.bedrock_agentcore.yaml') dockerfile_path=PosixPath('/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/Dockerfile') dockerignore_path=PosixPath('/home/sagemaker-user/Multi-Agent-Collaboration/graph_IntelligentLoanUnderwriting/05-hosting-a2a/.dockerignore') runtime='None' region='us-east-1' account_id='161615149547' execution_role='arn:aws:iam::161615149547:role/AWSOrchestratorAssistantAgentCoreRole-us-east-1' ecr_repository=None auto_create_ecr=True memory_id=None

# %%
launch_result = agentcore_runtime.launch()
print("Launch completed:", launch_result.agent_arn)

agent_arn = launch_result.agent_arn
# Out:
# 🚀 CodeBuild mode: building in cloud (RECOMMENDED - DEFAULT)
#    • Build ARM64 containers in the cloud with CodeBuild
#    • No local Docker required
# 💡 Available deployment modes:
#    • runtime.launch()                           → CodeBuild (current)
#    • runtime.launch(local=True)                 → Local development
#    • runtime.launch(local_build=True)           → Local build + cloud deploy (NEW)
# Creating memory resource for agent: aws_orchestrator_assistant
# ✅ MemoryManager initialized for region: us-east-1
# 🔎 Retrieving memory resource with ID: aws_orchestrator_assistant_mem-qhOp4oEGM3...
#   Found memory: aws_orchestrator_assistant_mem-qhOp4oEGM3
# Found existing memory in cloud: aws_orchestrator_assistant_mem-qhOp4oEGM3
# Existing memory has 0 strategies
# ✅ Using existing STM-only memory
# Starting CodeBuild ARM64 deployment for agent 'aws_orchestrator_assistant' to account 161615149547 (us-east-1)
# Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: aws_orchestrator_assistant
# ✅ ECR repository available: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-aws_orchestrator_assistant
# Using execution role from config: arn:aws:iam::161615149547:role/AWSOrchestratorAssistantAgentCoreRole-us-east-1
# Preparing CodeBuild project and uploading source...
# ✅ Reusing existing ECR repository: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-aws_orchestrator_assistant
# Getting or creating CodeBuild execution role for agent: aws_orchestrator_assistant
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-c5cab84b17
# Reusing existing CodeBuild execution role: arn:aws:iam::161615149547:role/AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-c5cab84b17
# Using dockerignore.template with 45 patterns for zip filtering
# Uploaded source to S3: aws_orchestrator_assistant/source.zip
# Updated CodeBuild project: bedrock-agentcore-aws_orchestrator_assistant-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.0s
# 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 8.2s
# 🔄 DOWNLOAD_SOURCE started (total: 9s)
# ✅ DOWNLOAD_SOURCE completed in 2.1s
# 🔄 BUILD started (total: 11s)
# ✅ BUILD completed in 16.4s
# 🔄 POST_BUILD started (total: 28s)
# ✅ POST_BUILD completed in 12.3s
# 🔄 COMPLETED started (total: 40s)
# ✅ COMPLETED completed in 1.0s
# 🎉 CodeBuild completed successfully in 0m 41s
# CodeBuild completed successfully
# ✅ CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# Passing memory configuration to agent: aws_orchestrator_assistant_mem-qhOp4oEGM3
# ✅ Agent created/updated: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/aws_orchestrator_assistant-HVbqmWHSQJ
# Observability is enabled, configuring Transaction Search...
# CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# X-Ray indexing rule already configured
# ✅ Transaction Search already fully configured
# 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-east-1#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/aws_orchestrator_assistant-HVbqmWHSQJ/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/aws_orchestrator_assistant-HVbqmWHSQJ
# Built with CodeBuild: bedrock-agentcore-aws_orchestrator_assistant-builder:a6a00d87-cdd9-4cad-baec-970e1d9fe5b9
# Deployed to cloud: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/aws_orchestrator_assistant-HVbqmWHSQJ
# ECR image: 161615149547.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-aws_orchestrator_assistant
# 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/aws_orchestrator_assistant-HVbqmWHSQJ-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/aws_orchestrator_assistant-HVbqmWHSQJ-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/aws_orchestrator_assistant-HVbqmWHSQJ-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/aws_orchestrator_assistant-HVbqmWHSQJ-DEFAULT --log-stream-name-prefix "2025/11/25/\[runtime-logs]" --since 1h
# Launch completed: arn:aws:bedrock-agentcore:us-east-1:161615149547:runtime/aws_orchestrator_assistant-HVbqmWHSQJ

# %% [markdown]
# **Check Deployment Status**
#
# Let's check if deployment is completed:

# %%
status_response = agentcore_runtime.status()
status = status_response.endpoint["status"]

print(f"Final status: {status}")
# Out:
# ✅ MemoryManager initialized for region: us-east-1
# 🔎 Retrieving memory resource with ID: aws_orchestrator_assistant_mem-qhOp4oEGM3...
#   Found memory: aws_orchestrator_assistant_mem-qhOp4oEGM3
# Retrieved Bedrock AgentCore status for: aws_orchestrator_assistant
# Final status: READY

# %% [markdown]
# #### 2.1 - Export and save outputs
#
# Export variables to be used in clean up notebook:

# %%
ORCHESTRATION_ID = launch_result.agent_id
ORCHESTRATION_ARN = launch_result.agent_arn
ORCHESTRATION_NAME = agent_name

# %store ORCHESTRATION_ID
# %store ORCHESTRATION_ARN
# %store ORCHESTRATION_NAME
# Out:
# Stored 'ORCHESTRATION_ID' (str)
# Stored 'ORCHESTRATION_ARN' (str)
# Stored 'ORCHESTRATION_NAME' (str)

# %% [markdown]
# ### 3 - Invoking A2A agents using an orchestrator agent
#
# Firstly, let's refresh the auth token:

# %%
from helpers.utils import reauthenticate_user

bearer_token = reauthenticate_user(
    COGNITO_CLIENT_ID,
    COGNITO_SECRET
)

# %% [markdown]
# Now, let's invoke our orchestrator to check AWS Docs, making a call to our first agent, using A2A:

# %%
import requests
import json
import uuid
from urllib.parse import quote

session_id = str(uuid.uuid4())
print(f'Invoking for session: {session_id}')

headers = {
    'Authorization': f'Bearer {bearer_token}',
    'Content-Type': 'application/json',
    'Accept': 'application/json',
    'X-Amzn-Bedrock-AgentCore-Runtime-Session-Id': session_id
}

prompt = {"prompt": "What is DynamoDB?"}

escaped_agent_arn = quote(ORCHESTRATION_ARN, safe='')

response = requests.post(
    f'https://bedrock-agentcore.{region}.amazonaws.com/runtimes/{escaped_agent_arn}/invocations',
    headers=headers,
    data=json.dumps(prompt)
)

for line in response.iter_lines(decode_unicode=True):
    if line.startswith('data: '):
        data = line[6:]
        try:
            parsed = json.loads(data)
            print(parsed)
        except:
            print(data)
# Out:
# Invoking for session: ff813662-5eaf-436e-8cf0-7c26d3465caa
# {'init_event_loop': True}
# {'start': True}
# {'start_event_loop': True}
# {'event': {'messageStart': {'role': 'assistant'}}}
# {'event': {'contentBlockStart': {'start': {'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'type': 'tool_use'}}, 'contentBlockIndex': 0}}}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ''}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': ''}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': ''}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': '{"message": '}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': '{"message": '}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": '}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': '"What is D'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': '"What is D'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is D'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'ynamoDB?'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': 'ynamoDB?'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB?'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ' Pl'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': ' Pl'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Pl'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'ease '}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': 'ease '}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please '}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'provide a b'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': 'provide a b'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please provide a b'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'rief s'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': 'rief s'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please provide a brief s'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'ummary cov'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': 'ummary cov'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please provide a brief summary cov'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'ering key '}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': 'ering key '}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please provide a brief summary covering key '}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'fe'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': 'fe'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please provide a brief summary covering key fe'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'atures, '}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': 'atures, '}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please provide a brief summary covering key features, '}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'use cases,'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': 'use cases,'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please provide a brief summary covering key features, use cases,'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ' and main'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': ' and main'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please provide a brief summary covering key features, use cases, and main'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ' benefi'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': ' benefi'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefi'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'ts."}'}}, 'contentBlockIndex': 0}}}
# {'delta': {'toolUse': {'input': 'ts."}'}}, 'current_tool_use': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': '{"message": "What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits."}'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0x82954e90b88c3c54, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockStop': {'contentBlockIndex': 0}}}
# {'event': {'messageStop': {'stopReason': 'tool_use'}}}
# {'event': {'metadata': {'usage': {'inputTokens': 554, 'outputTokens': 76, 'totalTokens': 630}, 'metrics': {'latencyMs': 2122}}}}
# {'message': {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}}
# {'message': {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}}
# {'start': True}
# {'start': True}
# {'start_event_loop': True}
# {'event': {'messageStart': {'role': 'assistant'}}}
# {'event': {'contentBlockDelta': {'delta': {'text': 'Let'}, 'contentBlockIndex': 0}}}
# {'data': 'Let', 'delta': {'text': 'Let'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' me provide you with information about DynamoDB base'}, 'contentBlockIndex': 0}}}
# {'data': ' me provide you with information about DynamoDB base', 'delta': {'text': ' me provide you with information about DynamoDB base'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': 'd on my knowledge:\n\n**Amazon'}, 'contentBlockIndex': 0}}}
# {'data': 'd on my knowledge:\n\n**Amazon', 'delta': {'text': 'd on my knowledge:\n\n**Amazon'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' DynamoDB** is'}, 'contentBlockIndex': 0}}}
# {'data': ' DynamoDB** is', 'delta': {'text': ' DynamoDB** is'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' a fully managed NoSQL database service'}, 'contentBlockIndex': 0}}}
# {'data': ' a fully managed NoSQL database service', 'delta': {'text': ' a fully managed NoSQL database service'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' provided by AWS'}, 'contentBlockIndex': 0}}}
# {'data': ' provided by AWS', 'delta': {'text': ' provided by AWS'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': '. Here are the key points'}, 'contentBlockIndex': 0}}}
# {'data': '. Here are the key points', 'delta': {'text': '. Here are the key points'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ':\n\n**What'}, 'contentBlockIndex': 0}}}
# {'data': ':\n\n**What', 'delta': {'text': ':\n\n**What'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' it is:**\n-'}, 'contentBlockIndex': 0}}}
# {'data': ' it is:**\n-', 'delta': {'text': ' it is:**\n-'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' Server'}, 'contentBlockIndex': 0}}}
# {'data': ' Server', 'delta': {'text': ' Server'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': 'less, No'}, 'contentBlockIndex': 0}}}
# {'data': 'less, No', 'delta': {'text': 'less, No'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': 'SQL database'}, 'contentBlockIndex': 0}}}
# {'data': 'SQL database', 'delta': {'text': 'SQL database'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': '\n- Fully'}, 'contentBlockIndex': 0}}}
# {'data': '\n- Fully', 'delta': {'text': '\n- Fully'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' managed by AWS ('}, 'contentBlockIndex': 0}}}
# {'data': ' managed by AWS (', 'delta': {'text': ' managed by AWS ('}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': 'no server'}, 'contentBlockIndex': 0}}}
# ...
# {'event': {'contentBlockDelta': {'delta': {'text': ' different'}, 'contentBlockIndex': 0}}}
# {'data': ' different', 'delta': {'text': ' different'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' attributes\n\nWould you like'}, 'contentBlockIndex': 0}}}
# {'data': ' attributes\n\nWould you like', 'delta': {'text': ' attributes\n\nWould you like'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' me to dive'}, 'contentBlockIndex': 0}}}
# {'data': ' me to dive', 'delta': {'text': ' me to dive'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' deeper into any specific aspect'}, 'contentBlockIndex': 0}}}
# {'data': ' deeper into any specific aspect', 'delta': {'text': ' deeper into any specific aspect'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' of DynamoDB?'}, 'contentBlockIndex': 0}}}
# {'data': ' of DynamoDB?', 'delta': {'text': ' of DynamoDB?'}, 'agent': <strands.agent.agent.Agent object at 0xffff6de2ac30>, 'event_loop_cycle_id': UUID('2df02220-3818-42a9-95fc-9cc3dc19eeb2'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff63a57b00>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bab2bd9c12d639ab7f538b8947b, span_id=0xdeb5e39aefdda223, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff6dc43170>, 'messages': [{'role': 'user', 'content': [{'text': 'What is DynamoDB?'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('1f4a96d1-25b5-4ff9-94c3-34303d6f3f01')}
# {'event': {'contentBlockStop': {'contentBlockIndex': 0}}}
# {'event': {'messageStop': {'stopReason': 'end_turn'}}}
# {'event': {'metadata': {'usage': {'inputTokens': 657, 'outputTokens': 297, 'totalTokens': 954}, 'metrics': {'latencyMs': 4621}}}}
# {'message': {'role': 'assistant', 'content': [{'text': 'Let me provide you with information about DynamoDB based on my knowledge:\n\n**Amazon DynamoDB** is a fully managed NoSQL database service provided by AWS. Here are the key points:\n\n**What it is:**\n- Serverless, NoSQL database\n- Fully managed by AWS (no server maintenance required)\n- Supports key-value and document data models\n\n**Key Features:**\n- **Performance**: Single-digit millisecond latency at any scale\n- **Scalability**: Automatic scaling up/down based on demand\n- **Availability**: Multi-region, multi-master replication\n- **Security**: Encryption at rest and in transit, fine-grained access control\n\n**Main Use Cases:**\n- Web and mobile applications\n- Gaming leaderboards and session stores\n- IoT data collection\n- Real-time personalization\n- Shopping carts and user profiles\n\n**Benefits:**\n- No capacity planning needed\n- Pay-per-use pricing model\n- Built-in backup and restore\n- Global tables for multi-region deployment\n- Integration with other AWS services\n\n**Data Model:**\n- Tables with items (rows) and attributes (columns)\n- Primary key required (partition key + optional sort key)\n- Flexible schema - items can have different attributes\n\nWould you like me to dive deeper into any specific aspect of DynamoDB?'}]}}
# {'result': AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Let me provide you with information about DynamoDB based on my knowledge:\n\n**Amazon DynamoDB** is a fully managed NoSQL database service provided by AWS. Here are the key points:\n\n**What it is:**\n- Serverless, NoSQL database\n- Fully managed by AWS (no server maintenance required)\n- Supports key-value and document data models\n\n**Key Features:**\n- **Performance**: Single-digit millisecond latency at any scale\n- **Scalability**: Automatic scaling up/down based on demand\n- **Availability**: Multi-region, multi-master replication\n- **Security**: Encryption at rest and in transit, fine-grained access control\n\n**Main Use Cases:**\n- Web and mobile applications\n- Gaming leaderboards and session stores\n- IoT data collection\n- Real-time personalization\n- Shopping carts and user profiles\n\n**Benefits:**\n- No capacity planning needed\n- Pay-per-use pricing model\n- Built-in backup and restore\n- Global tables for multi-region deployment\n- Integration with other AWS services\n\n**Data Model:**\n- Tables with items (rows) and attributes (columns)\n- Primary key required (partition key + optional sort key)\n- Flexible schema - items can have different attributes\n\nWould you like me to dive deeper into any specific aspect of DynamoDB?'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={'send_mcp_message': ToolMetrics(tool={'toolUseId': 'tooluse_pQovp_rpQwyUkxfeNbVX3g', 'name': 'send_mcp_message', 'input': {'message': 'What is DynamoDB? Please provide a brief summary covering key features, use cases, and main benefits.'}}, call_count=1, success_count=1, error_count=0, total_time=8.21434235572815)}, cycle_durations=[4.667111396789551], traces=[<strands.telemetry.metrics.Trace object at 0xffff6d2fdbe0>, <strands.telemetry.metrics.Trace object at 0xffff63a57b00>], accumulated_usage={'inputTokens': 1211, 'outputTokens': 373, 'totalTokens': 1584}, accumulated_metrics={'latencyMs': 6743}), state={}, interrupts=None, structured_output=None)}

# %%
import uuid

session_id = str(uuid.uuid4())
print(f'Invoking for session: {session_id}')

headers = {
    'Authorization': f'Bearer {bearer_token}',
    'Content-Type': 'application/json',
    'Accept': 'application/json',
    'X-Amzn-Bedrock-AgentCore-Runtime-Session-Id': session_id
}

prompt = {"prompt": "Give me the latest published blog for Bedrock AgentCore?"}

escaped_agent_arn = quote(ORCHESTRATION_ARN, safe='')

response = requests.post(
    f'https://bedrock-agentcore.{region}.amazonaws.com/runtimes/{escaped_agent_arn}/invocations',
    headers=headers,
    data=json.dumps(prompt)
)

for line in response.iter_lines(decode_unicode=True):
    if line.startswith('data: '):
        data = line[6:]
        try:
            parsed = json.loads(data)
            print(parsed)
        except:
            print(data)
# Out:
# Invoking for session: 10461e96-d545-4c1d-8cd2-19eb961eb7b0
# {'init_event_loop': True}
# {'start': True}
# {'start_event_loop': True}
# {'event': {'messageStart': {'role': 'assistant'}}}
# {'event': {'contentBlockDelta': {'delta': {'text': "I'll search for the"}, 'contentBlockIndex': 0}}}
# {'data': "I'll search for the", 'delta': {'text': "I'll search for the"}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'text': ' latest'}, 'contentBlockIndex': 0}}}
# {'data': ' latest', 'delta': {'text': ' latest'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'text': ' Bedrock AgentCore'}, 'contentBlockIndex': 0}}}
# {'data': ' Bedrock AgentCore', 'delta': {'text': ' Bedrock AgentCore'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'text': ' blog posts for you.'}, 'contentBlockIndex': 0}}}
# {'data': ' blog posts for you.', 'delta': {'text': ' blog posts for you.'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockStop': {'contentBlockIndex': 0}}}
# {'event': {'contentBlockStart': {'start': {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'type': 'tool_use'}}, 'contentBlockIndex': 1}}}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ''}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': ''}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': ''}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': '{"'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': '{"'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'messag'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'messag'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"messag'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'e": "Find'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'e": "Find'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ' t'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': ' t'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find t'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'he lat'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'he lat'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the lat'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'est publis'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'est publis'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest publis'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'he'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'he'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest publishe'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'd blo'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'd blo'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blo'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'g posts abou'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'g posts abou'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts abou'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 't Bedrock A'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 't Bedrock A'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock A'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'gentCore.'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'gentCore.'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore.'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ' Plea'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': ' Plea'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Plea'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'se provide '}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'se provide '}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide '}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'a brief'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'a brief'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ' summary o'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': ' summary o'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary o'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'f the most r'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'f the most r'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most r'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'ecent o'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'ecent o'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent o'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'ne including'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'ne including'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ' tit'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': ' tit'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including tit'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'le, pu'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'le, pu'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, pu'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'blicatio'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'blicatio'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publicatio'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'n d'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'n d'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication d'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'ate,'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'ate,'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date,'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ' and key '}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': ' and key '}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key '}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'highligh'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'highligh'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highligh'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'ts."}'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'ts."}'}}, 'current_tool_use': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': '{"message": "Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights."}'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86e59df0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x66f1c4ae298a4d4d, trace_flags=0x01, trace_state=[], is_remote=False))}
# {'event': {'contentBlockStop': {'contentBlockIndex': 1}}}
# {'event': {'messageStop': {'stopReason': 'tool_use'}}}
# {'event': {'metadata': {'usage': {'inputTokens': 562, 'outputTokens': 105, 'totalTokens': 667}, 'metrics': {'latencyMs': 1656}}}}
# {'message': {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}}
# {'message': {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}}
# {'start': True}
# {'start': True}
# {'start_event_loop': True}
# {'event': {'messageStart': {'role': 'assistant'}}}
# {'event': {'contentBlockDelta': {'delta': {'text': 'Let me try a'}, 'contentBlockIndex': 0}}}
# {'data': 'Let me try a', 'delta': {'text': 'Let me try a'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86f66cf0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x4cee7893f4acb358, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' different approach to get'}, 'contentBlockIndex': 0}}}
# {'data': ' different approach to get', 'delta': {'text': ' different approach to get'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86f66cf0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x4cee7893f4acb358, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' the latest'}, 'contentBlockIndex': 0}}}
# {'data': ' the latest', 'delta': {'text': ' the latest'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86f66cf0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x4cee7893f4acb358, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' Bedrock AgentCore blog information'}, 'contentBlockIndex': 0}}}
# {'data': ' Bedrock AgentCore blog information', 'delta': {'text': ' Bedrock AgentCore blog information'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86f66cf0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x4cee7893f4acb358, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db')}
# {'event': {'contentBlockDelta': {'delta': {'text': '.'}, 'contentBlockIndex': 0}}}
# {'data': '.', 'delta': {'text': '.'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86f66cf0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x4cee7893f4acb358, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db')}
# {'event': {'contentBlockStop': {'contentBlockIndex': 0}}}
# {'event': {'contentBlockStart': {'start': {'toolUse': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'name': 'send_blog_message', 'type': 'tool_use'}}, 'contentBlockIndex': 1}}}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ''}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': ''}}, 'current_tool_use': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'name': 'send_blog_message', 'input': ''}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86f66cf0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x4cee7893f4acb358, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db')}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': '{"messag'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': '{"messag'}}, 'current_tool_use': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'name': 'send_blog_message', 'input': '{"messag'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86f66cf0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x4cee7893f4acb358, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db')}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'e": "'}}, 'contentBlockIndex': 1}}}
# {'delta': {'toolUse': {'input': 'e": "'}}, 'current_tool_use': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'name': 'send_blog_message', 'input': '{"message": "'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff86f66cf0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x4cee7893f4acb358, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('bdb702cd-7925-4dd9-905e-3fa7977bc6db')}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'What are t'}}, 'contentBlockIndex': 1}}}
# ...
# {'event': {'contentBlockDelta': {'delta': {'text': ' for'}, 'contentBlockIndex': 0}}}
# {'data': ' for', 'delta': {'text': ' for'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('6bea83f0-d703-45c0-9e2f-5bccc383b685'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff855b71d0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x257280eec1d707f3, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}, {'role': 'assistant', 'content': [{'text': 'Let me try a different approach to get the latest Bedrock AgentCore blog information.'}, {'toolUse': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'name': 'send_blog_message', 'input': {'message': 'What are the most recent AWS blog posts about Amazon Bedrock AgentCore? Please summarize the latest one with title, date, and main points.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' technical'}, 'contentBlockIndex': 0}}}
# {'data': ' technical', 'delta': {'text': ' technical'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('6bea83f0-d703-45c0-9e2f-5bccc383b685'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff855b71d0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x257280eec1d707f3, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}, {'role': 'assistant', 'content': [{'text': 'Let me try a different approach to get the latest Bedrock AgentCore blog information.'}, {'toolUse': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'name': 'send_blog_message', 'input': {'message': 'What are the most recent AWS blog posts about Amazon Bedrock AgentCore? Please summarize the latest one with title, date, and main points.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' details about Bedrock'}, 'contentBlockIndex': 0}}}
# {'data': ' details about Bedrock', 'delta': {'text': ' details about Bedrock'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('6bea83f0-d703-45c0-9e2f-5bccc383b685'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff855b71d0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x257280eec1d707f3, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}, {'role': 'assistant', 'content': [{'text': 'Let me try a different approach to get the latest Bedrock AgentCore blog information.'}, {'toolUse': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'name': 'send_blog_message', 'input': {'message': 'What are the most recent AWS blog posts about Amazon Bedrock AgentCore? Please summarize the latest one with title, date, and main points.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776')}
# {'event': {'contentBlockDelta': {'delta': {'text': ' AgentCore instead?'}, 'contentBlockIndex': 0}}}
# {'data': ' AgentCore instead?', 'delta': {'text': ' AgentCore instead?'}, 'agent': <strands.agent.agent.Agent object at 0xffff87a244d0>, 'event_loop_cycle_id': UUID('6bea83f0-d703-45c0-9e2f-5bccc383b685'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff855b71d0>, 'event_loop_cycle_span': _Span(name="execute_event_loop_cycle", context=SpanContext(trace_id=0x69252bc4460f886d03b263ef002feb23, span_id=0x257280eec1d707f3, trace_flags=0x01, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff87987410>, 'messages': [{'role': 'user', 'content': [{'text': 'Give me the latest published blog for Bedrock AgentCore?'}]}, {'role': 'assistant', 'content': [{'text': "I'll search for the latest Bedrock AgentCore blog posts for you."}, {'toolUse': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'name': 'send_blog_message', 'input': {'message': 'Find the latest published blog posts about Bedrock AgentCore. Please provide a brief summary of the most recent one including title, publication date, and key highlights.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_hmS1pEsgRiGm98GdesIeUA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}, {'role': 'assistant', 'content': [{'text': 'Let me try a different approach to get the latest Bedrock AgentCore blog information.'}, {'toolUse': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'name': 'send_blog_message', 'input': {'message': 'What are the most recent AWS blog posts about Amazon Bedrock AgentCore? Please summarize the latest one with title, date, and main points.'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'status': 'success', 'content': [{'text': "Error: 'Task' object has no attribute 'parts'"}]}}]}], 'system_prompt': 'You are an AWS information orchestrator. \n\nAvailable agents:\n- AWS Documentation: Technical AWS service details\n- AWS Blogs: Latest AWS news and announcements\n\nIMPORTANT: Keep responses SHORT and FAST. Always request summaries from sub-agents.\n\nGuidelines:\n- Use parallel queries when possible\n- Timeout after 10 seconds per agent\n- Provide quick, actionable answers\n- If agents timeout, provide what you know\n', 'tool_config': {'tools': [{'toolSpec': {'name': 'send_mcp_message', 'description': 'Send message to AWS Docs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}, {'toolSpec': {'name': 'send_blog_message', 'description': 'Send message to AWS Blogs agent with timeout', 'inputSchema': {'json': {'properties': {'message': {'description': 'Parameter message', 'type': 'string'}}, 'required': ['message'], 'type': 'object'}}}}], 'toolChoice': {'auto': {}}}, 'event_loop_parent_cycle_id': UUID('deacac99-fdc0-4cd3-8bd6-79a2815b4776')}
# {'event': {'contentBlockStop': {'contentBlockIndex': 0}}}
# {'event': {'messageStop': {'stopReason': 'end_turn'}}}
# {'event': {'metadata': {'usage': {'inputTokens': 824, 'outputTokens': 160, 'totalTokens': 984}, 'metrics': {'latencyMs': 3007}}}}
# {'message': {'role': 'assistant', 'content': [{'text': 'I\'m experiencing technical issues accessing the AWS Blogs agent at the moment. Based on my knowledge, Amazon Bedrock Agents (which includes AgentCore functionality) has had several recent blog posts covering:\n\n- Multi-agent collaboration capabilities\n- Enhanced reasoning and tool integration\n- Improved function calling and workflow orchestration\n- New security and governance features\n\nFor the most up-to-date blog posts, I recommend checking the AWS Machine Learning Blog directly at aws.amazon.com/blogs/machine-learning/ and searching for "Bedrock Agents" or visiting the Amazon Bedrock documentation page which often links to the latest announcements.\n\nWould you like me to try accessing AWS documentation for technical details about Bedrock AgentCore instead?'}]}}
# {'result': AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'I\'m experiencing technical issues accessing the AWS Blogs agent at the moment. Based on my knowledge, Amazon Bedrock Agents (which includes AgentCore functionality) has had several recent blog posts covering:\n\n- Multi-agent collaboration capabilities\n- Enhanced reasoning and tool integration\n- Improved function calling and workflow orchestration\n- New security and governance features\n\nFor the most up-to-date blog posts, I recommend checking the AWS Machine Learning Blog directly at aws.amazon.com/blogs/machine-learning/ and searching for "Bedrock Agents" or visiting the Amazon Bedrock documentation page which often links to the latest announcements.\n\nWould you like me to try accessing AWS documentation for technical details about Bedrock AgentCore instead?'}]}, metrics=EventLoopMetrics(cycle_count=3, tool_metrics={'send_blog_message': ToolMetrics(tool={'toolUseId': 'tooluse_LB2fXoR1RTykcFKC9Ay7eA', 'name': 'send_blog_message', 'input': {'message': 'What are the most recent AWS blog posts about Amazon Bedrock AgentCore? Please summarize the latest one with title, date, and main points.'}}, call_count=2, success_count=2, error_count=0, total_time=15.353792667388916)}, cycle_durations=[3.057387113571167], traces=[<strands.telemetry.metrics.Trace object at 0xffff86e59df0>, <strands.telemetry.metrics.Trace object at 0xffff86f66cf0>, <strands.telemetry.metrics.Trace object at 0xffff855b71d0>], accumulated_usage={'inputTokens': 2079, 'outputTokens': 370, 'totalTokens': 2449}, accumulated_metrics={'latencyMs': 7311}), state={}, interrupts=None, structured_output=None)}

# %% [markdown]
# Congratulations, you have deployed the complete solution, using A2A protocol on Amazon AgentCore Runtime.
