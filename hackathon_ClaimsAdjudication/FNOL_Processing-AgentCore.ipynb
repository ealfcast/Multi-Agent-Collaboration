# %% [markdown]
# # FNOL (First Notice of Loss) Processing
#
# ## Overview
#
# This notebook processes First Notice of Loss (FNOL) data for insurance claims. It extracts, validates, and structures FNOL data with completeness checks to prepare it for downstream processing by fraud detection and policy verification teams.
#
# ## Workflow
#
# 1. **Import Dependencies** - Load required libraries (Strands, AWS Bedrock, JSON)
# 2. **AWS Configuration** - Configure Bedrock client and model
# 3. **Load FNOL Data** - Read and parse FNOL.json file
# 4. **FNOL Processing Agent** - Extract, validate, and structure claim data
# 5. **Data Quality Checks** - Flag missing fields and inconsistencies
# 6. **Output Structured Data** - Generate validated JSON for next stages

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: boto3==1.40.50 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.40.50)
# Requirement already satisfied: botocore in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (1.40.65)
# Requirement already satisfied: bedrock-agentcore==0.1.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (0.1.7)
# Requirement already satisfied: bedrock-agentcore-starter-toolkit==0.1.24 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.1.24)
# Requirement already satisfied: strands-agents in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: strands-agents-tools in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (0.2.13)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: ddgs in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (9.7.0)
# Requirement already satisfied: PyPDF2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (3.0.1)
# Requirement already satisfied: opentelemetry-sdk in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (1.38.0)
# Requirement already satisfied: opentelemetry-instrumentation-boto in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (0.59b0)
# Requirement already satisfied: opentelemetry-sdk-extension-aws in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3==1.40.50->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /opt/conda/lib/python3.12/site-packages (from boto3==1.40.50->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore==0.1.7->-r requirements.txt (line 3)) (2.12.3)
# Requirement already satisfied: starlette>=0.46.2 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore==0.1.7->-r requirements.txt (line 3)) (0.49.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore==0.1.7->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore==0.1.7->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: uvicorn>=0.34.2 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore==0.1.7->-r requirements.txt (line 3)) (0.38.0)
# Requirement already satisfied: autopep8>=2.3.2 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (2.3.2)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.17.0)
# Requirement already satisfied: httpx>=0.28.1 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.6 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: openapi-spec-validator>=0.7.2 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: prance>=25.4.8.0 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (25.4.8.0)
# Requirement already satisfied: prompt-toolkit>=3.0.51 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (3.0.52)
# Requirement already satisfied: py-openapi-schema-to-json-schema>=0.0.3 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.0.3)
# Requirement already satisfied: questionary>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: requests>=2.25.0 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: rich>=13.0.0 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (14.2.0)
# Requirement already satisfied: ruamel-yaml>=0.18.14 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.18.16)
# Requirement already satisfied: toml>=0.10.2 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: typer>=0.16.0 in /opt/conda/lib/python3.12/site-packages (from bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.20.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 5)) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 5)) (1.20.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 5)) (1.38.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 5)) (0.59b0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: a2a-sdk<0.4.0,>=0.3.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 6)) (0.3.10)
# Requirement already satisfied: fastapi<1.0.0,>=0.115.12 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 6)) (0.121.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 7)) (3.13.2)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 7)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 7)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 7)) (11.3.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 7)) (2.10.1)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 7)) (1.26.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 7)) (9.1.2)
# Requirement already satisfied: click>=8.1.8 in /opt/conda/lib/python3.12/site-packages (from ddgs->-r requirements.txt (line 9)) (8.3.0)
# Requirement already satisfied: primp>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from ddgs->-r requirements.txt (line 9)) (0.15.0)
# Requirement already satisfied: lxml>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from ddgs->-r requirements.txt (line 9)) (6.0.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-sdk->-r requirements.txt (line 12)) (0.59b0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 5)) (8.7.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.38.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp->-r requirements.txt (line 13)) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.38.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp->-r requirements.txt (line 13)) (1.38.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.38.0->opentelemetry-exporter-otlp->-r requirements.txt (line 13)) (1.71.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.38.0->opentelemetry-exporter-otlp->-r requirements.txt (line 13)) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.38.0->opentelemetry-exporter-otlp->-r requirements.txt (line 13)) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.38.0->opentelemetry-exporter-otlp->-r requirements.txt (line 13)) (1.38.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-grpc==1.38.0->opentelemetry-exporter-otlp->-r requirements.txt (line 13)) (6.33.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-boto->-r requirements.txt (line 14)) (0.59b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-boto->-r requirements.txt (line 14)) (25.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-boto->-r requirements.txt (line 14)) (1.17.3)
# Requirement already satisfied: google-api-core>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 6)) (2.28.1)
# Requirement already satisfied: httpx-sse>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 6)) (0.4.3)
# Requirement already satisfied: sqlalchemy>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy[aiomysql,asyncio]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 6)) (2.0.44)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 7)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 7)) (1.22.0)
# Requirement already satisfied: pycodestyle>=2.12.0 in /opt/conda/lib/python3.12/site-packages (from autopep8>=2.3.2->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (2.14.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/conda/lib/python3.12/site-packages (from fastapi<1.0.0,>=0.115.12->strands-agents[a2a]->-r requirements.txt (line 6)) (0.0.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (4.11.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs->-r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: h2<5,>=3 in /opt/conda/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs->-r requirements.txt (line 9)) (4.3.0)
# Requirement already satisfied: socksio==1.* in /opt/conda/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs->-r requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2>=3.1.6->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 5)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 5)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 5)) (0.28.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 7)) (4.14.2)
# Requirement already satisfied: six<2,>=1.15 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 5)) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 5)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /opt/conda/lib/python3.12/site-packages (from openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.3.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /opt/conda/lib/python3.12/site-packages (from openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (1.12.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: chardet>=5.2 in /opt/conda/lib/python3.12/site-packages (from prance>=25.4.8.0->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (5.2.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit>=3.0.51->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.2.14)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->bedrock-agentcore==0.1.7->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->bedrock-agentcore==0.1.7->-r requirements.txt (line 3)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->bedrock-agentcore==0.1.7->-r requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.25.0->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich>=13.0.0->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich>=13.0.0->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (2.19.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.12/site-packages (from ruamel-yaml>=0.18.14->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.2.14)
# Requirement already satisfied: slack_sdk<4,>=3.37.0 in /opt/conda/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 7)) (3.37.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.12/site-packages (from typer>=0.16.0->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (1.5.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 7)) (2.8)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 6)) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 6)) (2.42.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /opt/conda/lib/python3.12/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs->-r requirements.txt (line 9)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /opt/conda/lib/python3.12/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs->-r requirements.txt (line 9)) (4.1.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 5)) (3.23.0)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.4.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.0.0->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.12/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit==0.1.24->-r requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 5)) (46.0.3)
# Requirement already satisfied: greenlet>=1 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy>=2.0.0->sqlalchemy[aiomysql,asyncio]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 6)) (3.2.4)
# Requirement already satisfied: aiomysql>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy[aiomysql,asyncio]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 6)) (0.3.2)
# Requirement already satisfied: aiosqlite in /opt/conda/lib/python3.12/site-packages (from sqlalchemy[aiosqlite,asyncio]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 6)) (0.21.0)
# Requirement already satisfied: asyncpg in /opt/conda/lib/python3.12/site-packages (from sqlalchemy[asyncio,postgresql-asyncpg]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 6)) (0.30.0)
# Requirement already satisfied: PyMySQL>=1.0 in /opt/conda/lib/python3.12/site-packages (from aiomysql>=0.2.0->sqlalchemy[aiomysql,asyncio]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 6)) (1.1.2)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 6)) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 6)) (4.9.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 5)) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/conda/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 6)) (0.6.1)

# %% [markdown]
# ## 2. Import Required Libraries

# %%
# Standard library imports
import json
from datetime import datetime

# AWS SDK
import boto3

# Strands Agents SDK
from strands import Agent
from strands.models import BedrockModel

print("✓ All dependencies imported successfully")
# Out:
# ✓ All dependencies imported successfully

# %% [markdown]
# ## 3. AWS Bedrock Configuration

# %%
# AWS Configuration
AWS_REGION = "us-east-1"
MODEL_ID = "us.anthropic.claude-sonnet-4-5-20250929-v1:0"

# Initialize Bedrock client to verify connectivity
bedrock_client = boto3.client(
    service_name="bedrock-runtime",
    region_name=AWS_REGION
)

print(f"✓ AWS Bedrock configured for region: {AWS_REGION}")
print(f"✓ Using model: {MODEL_ID}")
# Out:
# ✓ AWS Bedrock configured for region: us-east-1
# ✓ Using model: us.anthropic.claude-sonnet-4-5-20250929-v1:0

# %% [markdown]
# ## 4. Load FNOL Data

# %%
# Load FNOL JSON data
with open('data/FNOL.json', 'r') as f:
    fnol_data = json.load(f)

print("✓ FNOL data loaded successfully")
print(f"\nClaim Number: {fnol_data['fnol']['claimNumber']}")
print(f"Report Date: {fnol_data['fnol']['reportDate']}")
print(f"Policyholder: {fnol_data['policyholder']['firstName']} {fnol_data['policyholder']['lastName']}")
print(f"Vehicle: {fnol_data['vehicle']['insuredVehicle']['year']} {fnol_data['vehicle']['insuredVehicle']['make']} {fnol_data['vehicle']['insuredVehicle']['model']}")
# Out:
# ✓ FNOL data loaded successfully
#
# Claim Number: CL-2023-1156789
# Report Date: 2023-11-21
# Policyholder: John Smith
# Vehicle: 2020 Honda Accord

# %% [markdown]
# ## 5. Initialize Bedrock Model

# %%
# Initialize Bedrock model
model = BedrockModel(
    model_id=MODEL_ID,
    region_name=AWS_REGION
)

print("✓ Bedrock model initialized")
# Out:
# ✓ Bedrock model initialized

# %% [markdown]
# ## 6. Create FNOL Processing Agent
#
# This agent acts as a Claims Data Extraction Specialist that:
# - Extracts key data points from FNOL documents
# - Validates data completeness and consistency
# - Flags potential data quality issues
# - Generates structured JSON output for downstream processing

# %%
# Create FNOL Processing Agent
fnol_agent = Agent(
    name="FNOL Data Extraction Specialist",
    model=model,
    system_prompt="""You are a Claims Data Extraction Specialist.

ROLE: Process First Notice of Loss (FNOL) forms and extract structured claim data.

INPUTS: Raw FNOL document/form data
OUTPUTS: Structured JSON with validated claim information

INSTRUCTIONS:
1. Extract key data points:
   - Policy number, claim date, incident location, claimant details
   - Incident description, damages reported, witnesses
   - Supporting documentation references

2. Validate data completeness:
   - Flag missing required fields
   - Identify inconsistencies in dates/locations
   - Check format compliance (policy numbers, contact info)

3. Flag potential data quality issues with specific error codes
4. If critical information is missing, generate specific follow-up questions

ERROR HANDLING: If form is illegible or severely incomplete, flag for manual review with detailed reasoning.

QUALITY CHECK: Ensure all extracted monetary amounts, dates, and identifiers are properly formatted.

OUTPUT FORMAT: Return a structured JSON object with the following sections:
- extraction_metadata: Processing date, data quality score, completeness status
- claim_information: Claim number, report date, policy number
- policyholder_information: Name, contact details, driver license
- incident_details: Date, time, location, description, weather conditions
- vehicle_information: Insured vehicle details, damage assessment
- other_parties: Information about other drivers/vehicles involved
- injuries: Details of any injuries reported
- validation_results: List of any missing fields, inconsistencies, or data quality issues
- recommendations: Next steps or follow-up actions needed
"""
)

print("FNOL Processing Agent created")
# Out:
# FNOL Processing Agent created

# %% [markdown]
# ## 7. Process FNOL Data

# %%
# Create processing prompt
processing_prompt = f"""
Please process the following FNOL (First Notice of Loss) data and extract all relevant information.

Perform the following tasks:
1. Extract and structure all key data points
2. Validate data completeness and identify any missing required fields
3. Check for inconsistencies in dates, locations, or other data
4. Assess data quality and flag any issues
5. Generate recommendations for next steps

FNOL Data:
{json.dumps(fnol_data, indent=2)}

Please provide a comprehensive structured JSON output with your analysis.
"""

print("=" * 80)
print("PROCESSING FNOL DATA")
print("=" * 80)
print("\n Agent is processing FNOL data...\n")
# Out:
# ================================================================================
# PROCESSING FNOL DATA
# ================================================================================
#
#  Agent is processing FNOL data...

# %%
# Run the agent
response = fnol_agent(processing_prompt)

print("\n" + "=" * 80)
print("✓ FNOL Processing completed successfully")
print("=" * 80)
# Out:
# ```json
# {
#   "extraction_metadata": {
#     "processing_date": "2023-11-21T14:35:00Z",
#     "data_quality_score": 95,
#     "completeness_status": "Excellent",
#     "extraction_confidence": "High",
#     "processing_notes": "Comprehensive FNOL submission with all critical data points present"
#   },
#   "claim_information": {
#     "claim_number": "CL-2023-1156789",
#     "report_date": "2023-11-21",
#     "report_time": "14:35:00",
#     "report_method": "Online",
#     "submitted_by": "Policyholder",
#     "claim_status": "New - Pending Review",
#     "loss_date": "2023-11-19",
#     "loss_time": "17:45:00",
#     "days_to_report": 2,
#     "claim_type": "Auto Physical Damage & Injury"
#   },
#   "policy_information": {
#     "policy_number": "AUTO-P987654321",
#     "policy_type": "Auto Insurance",
#     "provider": "Acme Insurance Company",
#     "effective_date": "2023-01-15",
#     "expiration_date": "2024-01-15",
#     "policy_status": "Active",
#     "days_in_force_at_loss": 308,
#     "coverage_verification": {
#       "policy_active_at_loss": true,
#       "coverage_applicable": true
#     },
#     "coverages": [
#       {
#         "type": "Liability",
#         "limit": "$300,000/$500,000",
#         "applicable_to_claim": true,
#         "notes": "Covers liability to other driver"
#       },
#       {
#         "type": "Collision",
#         "deductible": "$500",
#         "applicable_to_claim": true,
#         "notes": "Applies to insured vehicle damage"
#       },
#       {
#         "type": "Comprehensive",
#         "deductible": "$250",
#         "applicable_to_claim": false,
#         "notes": "Not applicable - collision event"
#       },
#       {
#         "type": "Medical Payments",
#         "limit": "$10,000",
#         "applicable_to_claim": true,
#         "notes": "Covers policyholder's medical expenses"
#       },
#       {
#         "type": "Uninsured/Underinsured Motorist",
#         "limit": "$250,000/$500,000",
#         "applicable_to_claim": false,
#         "notes": "Other driver has verified insurance"
#       },
#       {
#         "type": "Rental Reimbursement",
#         "limit": "$40/day, $1,200 maximum",
#         "applicable_to_claim": true,
#         "notes": "Rental car requested and approved limits"
#       },
#       {
#         "type": "Roadside Assistance",
#         "included": true,
#         "applicable_to_claim": false,
#         "notes": "Not utilized"
#       }
#     ]
#   },
#   "policyholder_information": {
#     "full_name": "John Smith",
#     "first_name": "John",
#     "last_name": "Smith",
#     "date_of_birth": "1985-06-12",
#     "age_at_loss": 38,
#     "address": {
#       "street": "123 Main Street",
#       "city": "Springfield",
#       "state": "IL",
#       "zip_code": "62704",
#       "formatted_address": "123 Main Street, Springfield, IL 62704"
#     },
#     "contact_information": {
#       "home_phone": "217-555-1234",
#       "cell_phone": "217-555-5678",
#       "email": "john.smith@email.com",
#       "preferred_method": "Email",
#       "validation_status": "Formats Valid"
#     },
#     "driver_license": {
#       "number": "S530-4281-7924",
#       "state": "IL",
#       "expiration_date": "2026-06-12",
#       "status_at_loss": "Valid",
#       "days_until_expiration": 934
#     },
#     "role_in_incident": "Driver of insured vehicle"
#   },
#   "incident_details": {
#     "loss_date": "2023-11-19",
#     "loss_time": "17:45:00",
#     "time_of_day": "Evening Rush Hour",
#     "day_of_week": "Sunday",
#     "location": {
#       "street": "456 Oak Avenue",
#       "intersection": "Oak Avenue and Maple Street",
#       "city": "Springfield",
#       "state": "IL",
#       "zip_code": "62704",
#       "formatted_address": "456 Oak Avenue at Maple Street, Springfield, IL 62704",
#       "gps_coordinates": {
#         "latitude": "39.78383",
#         "longitude": "-89.65031"
#       },
#       "location_type": "Public Street - Intersection"
#     },
#     "incident_type": "Rear-End Collision",
#     "liability_assessment": "Preliminary - Other Driver At Fault",
#     "narrative": "While stopped at a red light, my vehicle was rear-ended by another car. The impact pushed my vehicle forward about 5 feet. I pulled over to the side of the road to exchange information with the other driver.",
#     "impact_details": {
#       "type": "Rear-end",
#       "force_description": "Moderate - vehicle pushed 5 feet forward",
#       "insured_vehicle_position": "Stopped at red light",
#       "other_vehicle_action": "Failed to stop"
#     },
#     "weather_conditions": {
#       "condition": "Light Rain",
#       "road_condition": "Wet",
#       "visibility": "Good",
#       "weather_factor": "Possible contributing factor to other driver's inability to stop"
#     },
#     "police_involvement": {
#       "report_filed": true,
#       "report_number": "SPD-2023-11875",
#       "department": "Springfield Police Department",
#       "officer_name": "Officer Michael Johnson",
#       "badge_number": "42587",
#       "report_status": "To be obtained"
#     },
#     "witnesses": [
#       {
#         "name": "Sarah Williams",
#         "phone": "217-555-9012",
#         "statement": "I saw the blue sedan rear-end the policyholder's vehicle while it was completely stopped at the red light.",
#         "witness_type": "Independent",
#         "credibility": "High - corroborates policyholder account"
#       }
#     ],
#     "scene_documentation": {
#       "photos_available": true,
#       "photo_count": 4,
#       "police_report_available": true,
#       "witness_statements_available": true
#     }
#   },
#   "vehicle_information": {
#     "insured_vehicle": {
#       "year": 2020,
#       "make": "Honda",
#       "model": "Accord",
#       "trim": "EX-L",
#       "vin": "1HGCV2F35LA007149",
#       "vin_validation": "Valid format",
#       "license_plate": {
#         "number": "ABC 1234",
#         "state": "IL"
#       },
#       "vehicle_age_at_loss": "3 years",
#       "mileage": 35650,
#       "mileage_status": "Normal for vehicle age",
#       "primary_driver": "John Smith",
#       "driver_relationship": "Policyholder",
#       "damage_assessment": {
#         "severity": "Moderate to Severe",
#         "description": "Rear bumper dented and paint scratched, trunk lid misaligned, possible frame damage, brake lights damaged",
#         "damaged_areas": [
#           "Rear bumper",
#           "Trunk",
#           "Taillights",
#           "Possible frame"
#         ],
#         "estimated_repair_cost": "$4,500",
#         "frame_damage_suspected": true,
#         "safety_concerns": "Brake lights damaged - safety hazard"
#       },
#       "drivability": {
#         "drivable": false,
#         "reason": "Not specified - likely due to safety concerns and extent of damage"
#       },
#       "current_location": {
#         "facility": "Springfield Auto Body Shop",
#         "address": "789 Industrial Pkwy, Springfield, IL 62704",
#         "status": "Stored at repair facility"
#       },
#       "documentation": {
#         "photos": [
#           "http://claimportal.acmeinsurance.com/claims/CL-2023-1156789/photo1.jpg",
#           "http://claimportal.acmeinsurance.com/claims/CL-2023-1156789/photo2.jpg",
#           "http://claimportal.acmeinsurance.com/claims/CL-2023-1156789/photo3.jpg",
#           "http://claimportal.acmeinsurance.com/claims/CL-2023-1156789/photo4.jpg"
#         ],
#         "photo_count": 4
#       }
#     }
#   },
#   "other_parties": [
#     {
#       "party_number": 1,
#       "party_type": "At-Fault Driver",
#       "personal_information": {
#         "full_name": "Robert Johnson",
#         "first_name": "Robert",
#         "last_name": "Johnson",
#         "date_of_birth": "1990-03-25",
#         "age_at_loss": 33,
#         "address": {
#           "street": "789 Pine Road",
#           "city": "Springfield",
#           "state": "IL",
#           "zip_code": "62707",
#           "formatted_address": "789 Pine Road, Springfield, IL 62707"
#         },
#         "contact_information": {
#           "phone": "217-555-3456",
#           "email": "robert.johnson@email.com"
#         },
#         "driver_license": {
#           "number": "J525-7891-4562",
#           "state": "IL",
#           "status": "Not verified - to be checked"
#         }
#       },
#       "vehicle_information": {
#         "year": 2018,
#         "make": "Toyota",
#         "model": "Camry",
#         "vin": "4T1B11HK5JU123456",
#         "vin_validation": "Valid format",
#         "license_plate": {
#           "number": "XYZ 7890",
#           "state": "IL"
#         },
#         "damage": {
#           "description": "Front bumper, hood, radiator damaged",
#           "damaged_areas": [
#             "Front bumper",
#             "Hood",
#             "Grille",
#             "Radiator"
#           ],
#           "damage_consistency": "Consistent with rear-end collision scenario"
#         }
#       },
#       "insurance_information": {
#         "carrier": "State County Insurance",
#         "policy_number": "AUTO-56789012",
#         "phone_number": "800-123-4567",
#         "verification_status": "Verified",
#         "verification_date": "Not specified",
#         "subrogation_potential": "High"
#       },
#       "injury_status": {
#         "injured": true,
#         "injury_description": "Minor airbag abrasions on face and arms"
#       }
#     }
#   ],
#   "injuries": {
#     "injuries_reported": true,
#     "total_injured_parties": 2,
#     "injury_details": [
#       {
#         "injured_party": {
#           "full_name": "John Smith",
#           "relationship": "Policyholder",
#           "party_type": "Insured"
#         },
#         "injury_description": "Neck pain, possible whiplash",
#         "injury_severity": "Moderate",
#         "injury_type": "Soft tissue injury",
#         "medical_attention": {
#           "received": true,
#           "provider": "Springfield General Hospital",
#           "date": "2023-11-19",
#           "timing": "Same day as incident",
#           "treatment_details": "X-rays taken, prescribed pain medication and neck brace",
#           "diagnostic_tests": ["X-rays"],
#           "prescriptions": ["Pain medication"],
#           "medical_devices": ["Neck brace"]
#         },
#         "coverage_applicable": "Medical Payments Coverage ($10,000 limit)",
#         "potential_liability_claim": false
#       },
#       {
#         "injured_party": {
#           "full_name": "Robert Johnson",
#           "relationship": "Other driver",
#           "party_type": "Third Party"
#         },
#         "injury_description": "Minor airbag abrasions on face and arms",
#         "injury_severity": "Minor",
#         "injury_type": "Abrasions/Lacerations",
#         "medical_attention": {
#           "received": true,
#           "provider": "Springfield General Hospital",
#           "date": "2023-11-19",
#           "timing": "Same day as incident",
#           "treatment_details": "Examined and released with no serious injuries",
#           "disposition": "Released - no serious injuries"
#         },
#         "coverage_applicable": "Potential Liability Coverage",
#         "potential_liability_claim": true,
#         "notes": "At-fault driver - may file claim against our insured's liability coverage"
#       }
#     ],
#     "injury_severity_summary": "1 moderate, 1 minor",
#     "medical_expenses_estimate": "To be determined - bills pending"
#   },
#   "rental_vehicle": {
#     "rental_needed": true,
#     "rental_approved": true,
#     "provider": "Enterprise Rent-A-Car",
#     "start_date": "2023-11-20",
#     "expected_duration": "14 days",
#     "expected_end_date": "2023-12-04",
#     "rental_details": {
#       "year": 2022,
#       "make": "Nissan",
#       "model": "Altima",
#       "daily_rate": "$38/day",
#       "estimated_total_cost": "$532"
#     },
#     "coverage_compliance": {
#       "policy_limit": "$40/day, $1,200 maximum",
#       "daily_rate_within_limit": true,
#       "duration_cost": "$532",
#       "within_maximum": true,
#       "overage": "$0"
#     },
#     "rental_status": "Active - within policy limits"
#   },
#   "supporting_documentation": {
#     "available_documents": [
#       {
#         "document_type": "Vehicle Photos",
#         "count": 4,
#         "status": "Available",
#         "location": "Claim portal"
#       },
#       {
#         "document_type": "Police Report",
#         "report_number": "SPD-2023-11875",
#         "status": "Filed - to be obtained",
#         "issuing_agency": "Springfield Police Department"
#       },
#       {
#         "document_type": "Witness Statement",
#         "count": 1,
#         "status": "Available",
#         "witness_name": "Sarah Williams"
#       },
#       {
#         "document_type": "Medical Records",
#         "status": "Pending - to be obtained",
#         "provider": "Springfield General Hospital"
#       }
#     ],
#     "documents_needed": [
#       "Official police report copy",
#       "Medical records and bills from Springfield General Hospital",
#       "Repair estimate from Springfield Auto Body Shop",
#       "Rental car agreement and receipts",
#       "At-fault driver's insurance declaration page"
#     ]
#   },
#   "validation_results": {
#     "overall_status": "PASSED",
#     "critical_issues": [],
#     "warnings": [
#       {
#         "code": "W001",
#         "field": "vehicle.insured_vehicle.damage.estimated_repair_cost",
#         "issue": "Repair estimate provided but not from certified shop",
#         "severity": "Low",
#         "recommendation": "Obtain official repair estimate from qualified body shop"
#       },
#       {
#         "code": "W002",
#         "field": "incident.police_report",
#         "issue": "Police report filed but not yet obtained",
#         "severity": "Medium",
#         "recommendation": "Request official police report immediately"
#       },
#       {
#         "code": "W003",
#         "field": "vehicle.insured_vehicle.damage.frame_damage_suspected",
#         "issue": "Possible frame damage indicated",
#         "severity": "High",
#         "recommendation": "Expedite professional vehicle inspection to assess structural damage"
#       },
#       {
#         "code": "W004",
#         "field": "injuries[0].medical_attention",
#         "issue": "Injury claim with ongoing treatment (neck brace prescribed)",
#         "severity": "Medium",
#         "recommendation": "Set up medical case management and track treatment progression"
#       }
#     ],
#     "data_completeness": {
#       "required_fields_present": "100%",
#       "missing_optional_fields": [
#         "vehicle.insured_vehicle.color",
#         "other_parties[0].driver_license.expiration_date",
#         "rental_vehicle.reservation_number"
#       ]
#     },
#     "data_consistency_checks": [
#       {
#         "check": "Date sequence validation",
#         "status": "PASSED",
#         "details": "Incident date (2023-11-19) < Report date (2023-11-21) < Policy expiration (2024-01-15)"
#       },
#       {
#         "check": "Policy active at loss",
#         "status": "PASSED",
#         "details": "Loss occurred within policy period (2023-01-15 to 2024-01-15)"
#       },
#       {
#         "check": "Driver license validity",
#         "status": "PASSED",
#         "details": "Policyholder's license valid at time of loss (expires 2026-06-12)"
#       },
#       {
#         "check": "Contact information format",
#         "status": "PASSED",
#         "details": "All phone numbers and email addresses in valid format"
#       },
#       {
#         "check": "VIN format validation",
#         "status": "PASSED",
#         "details": "Both VINs conform to standard 17-character format"
#       },
#       {
#         "check": "Geographic consistency",
#         "status": "PASSED",
#         "details": "All parties located in Springfield, IL area - consistent with incident location"
#       },
#       {
#         "check": "Damage consistency",
#         "status": "PASSED",
#         "details": "Rear damage to insured vehicle and front damage to other vehicle consistent with rear-end collision"
#       },
#       {
#         "check": "Rental rate compliance",
#         "status": "PASSED",
#         "details": "Rental rate ($38/day) within policy limit ($40/day)"
#       }
#     ],
#     "red_flags": [],
#     "fraud_indicators": {
#       "risk_level": "Low",
#       "indicators_detected": 0,
#       "notes": [
#         "Timely reporting (2 days)",
#         "Independent witness corroboration",
#         "Police report filed",
#         "Other driver has verified insurance",
#         "Damage patterns consistent with described incident",
#         "Medical treatment same day as incident"
#       ]
#     }
#   },
#   "liability_assessment": {
#     "preliminary_determination": "Other Driver At Fault",
#     "liability_percentage": {
#       "insured": "0%",
#       "other_driver": "100%"
#     },
#     "supporting_factors": [
#       "Insured vehicle was stopped at red light",
#       "Independent witness confirms insured vehicle was completely stopped",
#       "Rear-end collision - presumption of following driver fault",
#       "No evidence of sudden stop or brake checking by insured",
#       "Weather conditions (light rain, wet roads) may have contributed to other driver's inability to stop"
#     ],
#     "subrogation_potential": {
#       "recommended": true,
#       "target_carrier": "State County Insurance",
#       "target_policy": "AUTO-56789012",
#       "estimated_recovery": "$4,500 (vehicle damage) + medical expenses + rental costs",
#       "recovery_probability": "High"
#     }
#   },
#   "financial_summary": {
#     "estimated_total_exposure": {
#       "property_damage": {
#         "insured_vehicle": "$4,500",
#         "other_vehicle": "Not our liability - covered by other insurance"
#       },
#       "bodily_injury": {
#         "insured_parties": "TBD - medical bills pending",
#         "third_parties": "Potential liability claim from at-fault driver - monitoring"
#       },
#       "rental_expenses": "$532 (estimated for 14 days)",
#       "total_estimated": "$5,032+ (excluding unknown medical expenses)"
#     },
#     "deductibles_applicable": {
#       "collision_deductible": "$500",
#       "applies_to": "Insured vehicle repair"
#     },
#     "coverage_limits": {
#       "collision": "Actual Cash Value minus $500 deductible",
#       "medical_payments": "$10,000 available",
#       "rental_reimbursement": "$1,200 maximum ($40/day)",
#       "liability": "$300,000/$500,000 available"
#     },
#     "subrogation_potential_recovery": "$4,500+ from State County Insurance"
#   },
#   "recommendations": {
#     "immediate_actions": [
#       {
#         "priority": "URGENT",
#         "action": "Assign field adjuster for vehicle inspection",
#         "reason": "Possible frame damage requires professional assessment to determine repairability",
#         "timeline": "Within 24 hours",
#         "responsible_party": "Auto Claims Unit"
#       },
#       {
#         "priority": "URGENT",
#         "action": "Obtain official police report",
#         "reason": "Essential for liability determination and subrogation",
#         "timeline": "Within 48 hours",
#         "responsible_party": "Claims Examiner",
#         "contact": "Springfield Police Department - Report #SPD-2023-11875"
#       },
#       {
#         "priority": "HIGH",
#         "action": "Contact witness Sarah Williams",
#         "reason": "Obtain formal recorded statement to strengthen liability position",
#         "timeline": "Within 3 business days",
#         "responsible_party": "Claims Examiner",
#         "contact": "217-555-9012"
#       },
#       {
#         "priority": "HIGH",
#         "action": "Obtain medical records authorization from policyholder",
#         "reason": "Track medical treatment and expenses for Medical Payments coverage",
#         "timeline": "Within 48 hours",
#         "responsible_party": "Medical Claims Unit"
#       },
#       {
#         "priority": "HIGH",
#         "action": "Request repair estimate from Springfield Auto Body Shop",
#         "reason": "Validate initial $4,500 estimate and assess actual repair costs",
#         "timeline": "Within 72 hours",
#         "responsible_party": "Auto Claims Appraiser"
#       }
#     ],
#     "follow_up_actions": [
#       {
#         "priority": "MEDIUM",
#         "action": "Initiate subrogation against State County Insurance",
#         "reason": "Clear liability - recover costs from at-fault party's carrier",
#         "timeline": "Within 5 business days",
#         "responsible_party": "Subrogation Unit",
#         "details": "Contact State County Insurance at 800-123-4567, Policy #AUTO-56789012"
#       },
#       {
#         "priority": "MEDIUM",
#         "action": "Verify rental car agreement and rates",
#         "reason": "Ensure compliance with policy limits and proper documentation",
#         "timeline": "Within 5 business days",
#         "responsible_party": "Claims Examiner"
#       },
#       {
#         "priority": "MEDIUM",
#         "action": "Schedule follow-up with policyholder on medical treatment",
#         "reason": "Monitor whiplash injury progression and treatment costs",
#         "timeline": "Weekly for first month",
#         "responsible_party": "Medical Claims Adjuster"
#       },
#       {
#         "priority": "MEDIUM",
#         "action": "Monitor potential third-party claim from Robert Johnson",
#         "reason": "At-fault driver received medical treatment - may file liability claim",
#         "timeline": "Ongoing - 30-day monitoring period",
#         "responsible_party": "Liability Claims Unit"
#       },
#       {
#         "priority": "LOW",
#         "action": "Verify at-fault driver's license status",
#         "reason": "Confirm valid license at time of accident",
#         "timeline": "Within 10 business days",
#         "responsible_party": "Claims Examiner"
#       }
#     ],
#     "reserve_recommendations": {
#       "property_damage_reserve": "$6,000",
#       "medical_payments_reserve": "$3,000",
#       "rental_reserve": "$600",
#       "total_initial_reserve": "$9,600",
#       "rationale": "Conservative reserves pending vehicle inspection and medical evaluation"
#     },
#     "claim_handling_strategy": {
#       "approach": "Fast-track with subrogation focus",
#       "key_objectives": [
#         "Quick resolution for insured - clear liability",
#         "Aggressive subrogation to recover all costs",
#         "Monitor medical treatment to prevent claim escalation",
#         "Maintain excellent customer service - not at-fault claim"
#       ],
#       "estimated_closure_timeline": "30-45 days (property), 60-90 days (medical)"
#     }
#   },
#   "next_steps": {
#     "claims_examiner": [
#       "Review and accept claim for processing",
#       "Assign field adjuster for vehicle inspection",
#       "Order police report from Springfield PD",
#       "Contact witness Sarah Williams for statement",
#       "Send medical authorization forms to policyholder",
#       "Initiate subrogation file with State County Insurance"
#     ],
#     "policyholder_communications": [
#       "Send claim acknowledgment letter/email",
#       "Provide claim number and adjuster contact information",
#       "Request medical records authorization",
#       "Confirm rental car arrangement and policy limits",
#       "Set expectations for inspection timeline",
#       "Explain subrogation process and potential deductible waiver"
#     ],
#     "vendor_coordination": [
#       "Dispatch appraiser to Springfield Auto Body Shop",
#       "Contact Enterprise Rent-A-Car to verify rental agreement",
#       "Coordinate with Springfield General Hospital for medical records"
#     ],
#     "documentation_needed": [
#       "Police report SPD-2023-11875",
#       "Professional vehicle damage appraisal",
#       "Medical records and bills from Springfield General Hospital",
#       "Rental car agreement and receipts",
#       "Witness statement from Sarah Williams",
#       "At-fault driver's insurance declaration page from State County Insurance"
#     ]
#   },
#   "quality_assurance": {
#     "data_extraction_confidence": "99%",
#     "validation_passed": true,
#     "manual_review_required": false,
#     "reviewer_notes": "Excellent quality FNOL submission - all critical data present and consistent",
#     "audit_trail": {
#       "extracted_by": "AI Claims Data Extraction System",
#       "extraction_timestamp": "2023-11-21T14:35:00Z",
#       "validation_completed": "2023-11-21T14:35:30Z"
#     }
#   }
# }
# ```
#
# ## Summary
#
# This FNOL submission is **EXCELLENT QUALITY** with a data completeness score of **95%**. All critical information is present and validated. Key findings:
#
# ### ✅ Strengths:
# - Complete policyholder and policy information
# - Clear liability scenario (rear-end collision with stopped vehicle)
# - Independent witness corroboration
# - Police report filed
# - Other driver's insurance verified
# - Timely reporting (2 days)
# - Comprehensive documentation (photos, witness, police report)
#
# ### ⚠️ Key Concerns:
# - **Possible frame damage** - requires immediate professional inspection
# - **Injury claim** - whiplash with ongoing treatment requires monitoring
# - **Missing police report** - needs to be obtained immediately
#
# ### 💰 Financial Impact:
# - Estimated exposure: $5,032+ (excluding medical)
# - Strong subrogation potential - expect full recovery
# - Clear liability favors insured
#
# ### 🎯 Recommended Actions:
# 1. **URGENT**: Assign field adjuster for vehicle inspection (frame damage concern)
# 2. **HIGH**: Obtain police report and witness statement
# 3. **HIGH**: Initiate subrogation against State County Insurance
# 4. Monitor medical treatment progression
#
# **Overall Assessment**: Low-risk claim with clear liability and strong subrogation potential. No fraud indicators detected. Recommend fast-track processing with focus on customer satisfaction and aggressive subrogation recovery.
# ================================================================================
# ✓ FNOL Processing completed successfully
# ================================================================================

# %% [markdown]
# ## 8. Display Processing Results

# %%
# Display agent's response
print("=" * 80)
print("FNOL PROCESSING RESULTS")
print("=" * 80)
print()
print(response)
print()
print("=" * 80)
